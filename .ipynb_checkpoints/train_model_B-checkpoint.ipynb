# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import AdaBoostClassifier

# %%
data = pd.read_csv("./data_model_B.csv")
print(len(data))
X=data.drop(columns=["result", "home_team_goal", "away_team_goal"])
y=data["result"]
data
# Out:
# 25659
#        Unnamed: 0  year  home_team  away_team  home_team_goal  away_team_goal  \
# 0               0  2008       9987       9993               1               1
# 1               1  2008      10000       9994               0               0
# 2               2  2008       9984       8635               0               3
# 3               3  2008       9991       9998               5               0
# 4               4  2008       8203       8342               1               1
# ...           ...   ...        ...        ...             ...             ...
# 25654       25654  2015      10243      10191               3               3
# 25655       25655  2015      10190      10191               1               0
# 25656       25656  2015       9824      10199               1               2
# 25657       25657  2015       9956      10179               2               0
# 25658       25658  2015      10192       9931               4               3
#
#        result  home_team year  home_team buildUpPlaySpeed  \
# 0           0            2009                          45
# 1           0            2009                          65
# 2          -1            2009                          45
# 3           1            2009                          70
# 4           0            2009                          65
# ...       ...             ...                         ...
# 25654       0            2015                          62
# 25655       1            2015                          52
# 25656      -1            2015                          53
# 25657       1            2015                          50
# 25658       1            2015                          52
#
#        home_team buildUpPlayDribbling  ...  away_team year  \
# 0                                30.0  ...            2009
# 1                                30.0  ...            2009
# 2                                30.0  ...            2009
# 3                                30.0  ...            2011
# 4                                30.0  ...            2009
# ...                               ...  ...             ...
# 25654                            49.0  ...            2015
# 25655                            46.0  ...            2015
# 25656                            32.0  ...            2015
# 25657                            60.0  ...            2015
# 25658                            56.0  ...            2015
#
#        away_team buildUpPlaySpeed  away_team buildUpPlayDribbling  \
# 0                              35                            30.0
# 1                              60                            30.0
# 2                              50                            30.0
# 3                              50                            30.0
# 4                              35                            30.0
# ...                           ...                             ...
# 25654                          58                            59.0
# 25655                          58                            59.0
# 25656                          63                            51.0
# 25657                          61                            57.0
# 25658                          61                            63.0
#
#        away_team buildUpPlayPassing  away_team chanceCreationPassing  \
# 0                                35                               45
# 1                                60                               50
# 2                                35                               70
# 3                                50                               55
# 4                                40                               45
# ...                             ...                              ...
# 25654                            35                               64
# 25655                            35                               64
# 25656                            51                               54
# 25657                            37                               62
# 25658                            46                               66
#
#        away_team chanceCreationCrossing  away_team chanceCreationShooting  \
# 0                                    40                                50
# 1                                    40                                50
# 2                                    50                                60
# 3                                    48                                46
# 4                                    50                                45
# ...                                 ...                               ...
# 25654                                36                                66
# 25655                                36                                66
# 25656                                40                                66
# 25657                                50                                53
# 25658                                66                                54
#
#        away_team defencePressure  away_team defenceAggression  \
# 0                             70                           70
# 1                             65                           65
# 2                             70                           50
# 3                             46                           45
# 4                             60                           70
# ...                          ...                          ...
# 25654                         47                           45
# 25655                         47                           45
# 25656                         48                           53
# 25657                         45                           47
# 25658                         47                           58
#
#        away_team defenceTeamWidth
# 0                              70
# 1                              70
# 2                              70
# 3                              47
# 4                              70
# ...                           ...
# 25654                          53
# 25655                          53
# 25656                          50
# 25657                          54
# 25658                          53
#
# [25659 rows x 27 columns]

# %%
t_X,val_X,t_y,val_y=train_test_split(X,y,test_size=0.2)
train_X,test_X,train_y,test_y=train_test_split(t_X,t_y,test_size=0.2)

# %%
print("TRAIN: ",len(train_X),"    ",len(train_y))
print("TEST: ",len(test_X),"    ",len(test_y))
print("VALIDATION: ",len(val_X),"    ",len(val_y))
# Out:
# TRAIN:  16421      16421
# TEST:  4106      4106
# VALIDATION:  5132      5132

# %%
rf = RandomForestClassifier(n_estimators=200)
rf.fit(train_X, train_y)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
y_pred=rf.predict(test_X)
score = accuracy_score(test_y,y_pred)

print("RANDOM FOREST 200 trees:   " ,score)
# Out:
# RANDOM FOREST 200 trees:    0.46687773989283976

# %%
y_valpreds = rf.predict(val_X)
val_score = accuracy_score(val_y,y_valpreds)
val_score
# Out:
# 0.446024941543258

# %%
print("RANDOM FOREST 200 trees:   " ,score)
print("VALIDATION SCORE:  ",val_score)
# Out:
# RANDOM FOREST 200 trees:    0.46687773989283976
# VALIDATION SCORE:   0.446024941543258

# %%
ada=AdaBoostClassifier(n_estimators=80)
ada.fit(train_X, train_y)
# Out:
# AdaBoostClassifier(n_estimators=80)

# %%
y_pred_ada=ada.predict(test_X)
score_ada=accuracy_score(test_y,y_pred_ada)
score_ada
# Out:
# 0.48295177788602045
