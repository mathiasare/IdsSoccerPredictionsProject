# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import AdaBoostClassifier

# %%
data = pd.read_csv("./data_model_B.csv")
print(len(data))
X=data.drop(columns=["result", "home_team_goal", "away_team_goal", "Unnamed: 0"])
y=data["result"]
pd.set_option("display.max_rows", None, "display.max_columns", None)
data.corr()
# Out:
# 25659
#                                   Unnamed: 0      year  home_team  away_team  \
# Unnamed: 0                          1.000000  0.108059  -0.031904  -0.031913
# year                                0.108059  1.000000   0.068231   0.068220
# home_team                          -0.031904  0.068231   1.000000  -0.000360
# away_team                          -0.031913  0.068220  -0.000360   1.000000
# home_team_goal                      0.009084  0.004866  -0.012665   0.008217
# away_team_goal                      0.011935  0.027870   0.014839  -0.012924
# result                             -0.008101 -0.024398  -0.021080   0.013575
# home_team year                      0.104592  0.959822   0.082407   0.072964
# home_team buildUpPlaySpeed         -0.192950  0.069287   0.058953   0.016386
# home_team buildUpPlayDribbling      0.100344  0.639418   0.116678   0.071755
# home_team buildUpPlayPassing       -0.109190  0.046967   0.016058  -0.001867
# home_team chanceCreationPassing     0.060096  0.013807   0.009744  -0.005587
# home_team chanceCreationCrossing   -0.011507 -0.014893  -0.014622   0.013471
# home_team chanceCreationShooting    0.076824 -0.339679  -0.055780  -0.029246
# home_team defencePressure          -0.025366 -0.122188  -0.065193  -0.021959
# home_team defenceAggression        -0.129990 -0.144932  -0.033117  -0.002828
# home_team defenceTeamWidth          0.059553 -0.039786  -0.073971   0.002487
# away_team year                      0.104621  0.959829   0.072974   0.082388
# away_team buildUpPlaySpeed         -0.192950  0.069409   0.016407   0.058943
# away_team buildUpPlayDribbling      0.100529  0.639512   0.071667   0.116656
# away_team buildUpPlayPassing       -0.109148  0.046991  -0.001920   0.016083
# away_team chanceCreationPassing     0.060018  0.013899  -0.005672   0.009747
# away_team chanceCreationCrossing   -0.011622 -0.014905   0.013467  -0.014578
# away_team chanceCreationShooting    0.076765 -0.339565  -0.029240  -0.055745
# away_team defencePressure          -0.025416 -0.122268  -0.021945  -0.065193
# away_team defenceAggression        -0.130085 -0.144935  -0.002843  -0.033087
# away_team defenceTeamWidth          0.059499 -0.039935   0.002523  -0.073971
#
#                                   home_team_goal  away_team_goal    result  \
# Unnamed: 0                              0.009084        0.011935 -0.008101
# year                                    0.004866        0.027870 -0.024398
# home_team                              -0.012665        0.014839 -0.021080
# away_team                               0.008217       -0.012924  0.013575
# home_team_goal                          1.000000       -0.064490  0.624696
# away_team_goal                         -0.064490        1.000000 -0.633010
# result                                  0.624696       -0.633010  1.000000
# home_team year                          0.001405        0.025531 -0.025040
# home_team buildUpPlaySpeed             -0.011920        0.011064 -0.006395
# home_team buildUpPlayDribbling         -0.007046        0.005690 -0.011936
# home_team buildUpPlayPassing           -0.077830        0.034435 -0.065182
# home_team chanceCreationPassing         0.022339       -0.013452  0.026426
# home_team chanceCreationCrossing        0.007474       -0.010485  0.014449
# home_team chanceCreationShooting        0.035673       -0.038458  0.051024
# home_team defencePressure               0.064946       -0.042009  0.062243
# home_team defenceAggression             0.016673       -0.026448  0.025184
# home_team defenceTeamWidth              0.027531       -0.023457  0.027691
# away_team year                          0.007472        0.018994 -0.018515
# away_team buildUpPlaySpeed              0.001807        0.005582 -0.000353
# away_team buildUpPlayDribbling         -0.007767        0.011275 -0.018560
# away_team buildUpPlayPassing            0.031429       -0.063611  0.053070
# away_team chanceCreationPassing        -0.013738        0.023558 -0.029135
# away_team chanceCreationCrossing       -0.016635        0.008814 -0.020362
# away_team chanceCreationShooting       -0.033569        0.020656 -0.024512
# away_team defencePressure              -0.043193        0.059548 -0.063262
# away_team defenceAggression            -0.027612        0.016318 -0.023084
# away_team defenceTeamWidth             -0.023357        0.025729 -0.030304
#
#                                   home_team year  home_team buildUpPlaySpeed  \
# Unnamed: 0                              0.104592                   -0.192950
# year                                    0.959822                    0.069287
# home_team                               0.082407                    0.058953
# away_team                               0.072964                    0.016386
# home_team_goal                          0.001405                   -0.011920
# away_team_goal                          0.025531                    0.011064
# result                                 -0.025040                   -0.006395
# home_team year                          1.000000                    0.079638
# home_team buildUpPlaySpeed              0.079638                    1.000000
# home_team buildUpPlayDribbling          0.699589                    0.100362
# home_team buildUpPlayPassing            0.048740                    0.425641
# home_team chanceCreationPassing         0.013329                    0.326363
# home_team chanceCreationCrossing       -0.015436                    0.223276
# home_team chanceCreationShooting       -0.329687                    0.081436
# home_team defencePressure              -0.115631                    0.069423
# home_team defenceAggression            -0.131532                    0.160171
# home_team defenceTeamWidth             -0.039828                    0.097492
# away_team year                          0.964258                    0.076441
# away_team buildUpPlaySpeed              0.076580                    0.279670
# away_team buildUpPlayDribbling          0.678391                    0.085308
# away_team buildUpPlayPassing            0.043033                    0.185763
# away_team chanceCreationPassing         0.012189                    0.114882
# away_team chanceCreationCrossing       -0.017995                    0.126045
# away_team chanceCreationShooting       -0.319645                   -0.028116
# away_team defencePressure              -0.102874                    0.052631
# away_team defenceAggression            -0.120351                    0.147713
# away_team defenceTeamWidth             -0.033280                    0.090506
#
#                                   home_team buildUpPlayDribbling  \
# Unnamed: 0                                              0.100344
# year                                                    0.639418
# home_team                                               0.116678
# away_team                                               0.071755
# home_team_goal                                         -0.007046
# away_team_goal                                          0.005690
# result                                                 -0.011936
# home_team year                                          0.699589
# home_team buildUpPlaySpeed                              0.100362
# home_team buildUpPlayDribbling                          1.000000
# home_team buildUpPlayPassing                            0.008426
# home_team chanceCreationPassing                         0.033467
# home_team chanceCreationCrossing                       -0.002583
# home_team chanceCreationShooting                       -0.132370
# home_team defencePressure                              -0.047260
# home_team defenceAggression                            -0.053371
# home_team defenceTeamWidth                             -0.012829
# away_team year                                          0.678326
# away_team buildUpPlaySpeed                              0.085575
# away_team buildUpPlayDribbling                          0.765930
# away_team buildUpPlayPassing                            0.011320
# away_team chanceCreationPassing                         0.010837
# away_team chanceCreationCrossing                       -0.023898
# away_team chanceCreationShooting                       -0.147523
# away_team defencePressure                              -0.051699
# away_team defenceAggression                            -0.025192
# away_team defenceTeamWidth                             -0.027124
#
#                                   home_team buildUpPlayPassing  \
# Unnamed: 0                                           -0.109190
# year                                                  0.046967
# home_team                                             0.016058
# away_team                                            -0.001867
# home_team_goal                                       -0.077830
# away_team_goal                                        0.034435
# result                                               -0.065182
# home_team year                                        0.048740
# home_team buildUpPlaySpeed                            0.425641
# home_team buildUpPlayDribbling                        0.008426
# home_team buildUpPlayPassing                          1.000000
# home_team chanceCreationPassing                       0.198196
# home_team chanceCreationCrossing                      0.251511
# home_team chanceCreationShooting                     -0.091599
# home_team defencePressure                            -0.055237
# home_team defenceAggression                           0.160138
# home_team defenceTeamWidth                            0.037293
# away_team year                                        0.043040
# away_team buildUpPlaySpeed                            0.185863
# away_team buildUpPlayDribbling                        0.011697
# away_team buildUpPlayPassing                          0.225467
# away_team chanceCreationPassing                       0.113880
# away_team chanceCreationCrossing                      0.130236
# away_team chanceCreationShooting                     -0.056545
# away_team defencePressure                             0.098418
# away_team defenceAggression                           0.173618
# away_team defenceTeamWidth                            0.113278
#
#                                   home_team chanceCreationPassing  \
# Unnamed: 0                                               0.060096
# year                                                     0.013807
# home_team                                                0.009744
# away_team                                               -0.005587
# home_team_goal                                           0.022339
# away_team_goal                                          -0.013452
# result                                                   0.026426
# home_team year                                           0.013329
# home_team buildUpPlaySpeed                               0.326363
# home_team buildUpPlayDribbling                           0.033467
# home_team buildUpPlayPassing                             0.198196
# home_team chanceCreationPassing                          1.000000
# home_team chanceCreationCrossing                         0.259556
# home_team chanceCreationShooting                         0.142328
# home_team defencePressure                                0.200663
# home_team defenceAggression                              0.182458
# home_team defenceTeamWidth                               0.133127
# away_team year                                           0.012123
# away_team buildUpPlaySpeed                               0.115379
# away_team buildUpPlayDribbling                           0.010714
# away_team buildUpPlayPassing                             0.114025
# away_team chanceCreationPassing                          0.157844
# away_team chanceCreationCrossing                         0.129378
# away_team chanceCreationShooting                        -0.017056
# away_team defencePressure                                0.070390
# away_team defenceAggression                              0.141900
# away_team defenceTeamWidth                               0.062265
#
#                                   home_team chanceCreationCrossing  \
# Unnamed: 0                                               -0.011507
# year                                                     -0.014893
# home_team                                                -0.014622
# away_team                                                 0.013471
# home_team_goal                                            0.007474
# away_team_goal                                           -0.010485
# result                                                    0.014449
# home_team year                                           -0.015436
# home_team buildUpPlaySpeed                                0.223276
# home_team buildUpPlayDribbling                           -0.002583
# home_team buildUpPlayPassing                              0.251511
# home_team chanceCreationPassing                           0.259556
# home_team chanceCreationCrossing                          1.000000
# home_team chanceCreationShooting                         -0.017881
# home_team defencePressure                                 0.029224
# home_team defenceAggression                               0.084233
# home_team defenceTeamWidth                                0.078072
# away_team year                                           -0.017790
# away_team buildUpPlaySpeed                                0.125727
# away_team buildUpPlayDribbling                           -0.023785
# away_team buildUpPlayPassing                              0.130143
# away_team chanceCreationPassing                           0.129179
# away_team chanceCreationCrossing                          0.178711
# away_team chanceCreationShooting                         -0.034985
# away_team defencePressure                                -0.009225
# away_team defenceAggression                               0.083525
# away_team defenceTeamWidth                                0.010853
#
#                                   home_team chanceCreationShooting  \
# Unnamed: 0                                                0.076824
# year                                                     -0.339679
# home_team                                                -0.055780
# away_team                                                -0.029246
# home_team_goal                                            0.035673
# away_team_goal                                           -0.038458
# result                                                    0.051024
# home_team year                                           -0.329687
# home_team buildUpPlaySpeed                                0.081436
# home_team buildUpPlayDribbling                           -0.132370
# home_team buildUpPlayPassing                             -0.091599
# home_team chanceCreationPassing                           0.142328
# home_team chanceCreationCrossing                         -0.017881
# home_team chanceCreationShooting                          1.000000
# home_team defencePressure                                 0.209826
# home_team defenceAggression                               0.116424
# home_team defenceTeamWidth                                0.139992
# away_team year                                           -0.319805
# away_team buildUpPlaySpeed                               -0.027759
# away_team buildUpPlayDribbling                           -0.147707
# away_team buildUpPlayPassing                             -0.056146
# away_team chanceCreationPassing                          -0.016977
# away_team chanceCreationCrossing                         -0.035703
# away_team chanceCreationShooting                          0.214471
# away_team defencePressure                                 0.056098
# away_team defenceAggression                               0.059727
# away_team defenceTeamWidth                                0.029617
#
#                                   home_team defencePressure  \
# Unnamed: 0                                        -0.025366
# year                                              -0.122188
# home_team                                         -0.065193
# away_team                                         -0.021959
# home_team_goal                                     0.064946
# away_team_goal                                    -0.042009
# result                                             0.062243
# home_team year                                    -0.115631
# home_team buildUpPlaySpeed                         0.069423
# home_team buildUpPlayDribbling                    -0.047260
# home_team buildUpPlayPassing                      -0.055237
# home_team chanceCreationPassing                    0.200663
# home_team chanceCreationCrossing                   0.029224
# home_team chanceCreationShooting                   0.209826
# home_team defencePressure                          1.000000
# home_team defenceAggression                        0.434220
# home_team defenceTeamWidth                         0.579072
# away_team year                                    -0.102762
# away_team buildUpPlaySpeed                         0.052763
# away_team buildUpPlayDribbling                    -0.051807
# away_team buildUpPlayPassing                       0.098717
# away_team chanceCreationPassing                    0.070001
# away_team chanceCreationCrossing                  -0.008857
# away_team chanceCreationShooting                   0.056726
# away_team defencePressure                          0.273275
# away_team defenceAggression                        0.244445
# away_team defenceTeamWidth                         0.236314
#
#                                   home_team defenceAggression  \
# Unnamed: 0                                          -0.129990
# year                                                -0.144932
# home_team                                           -0.033117
# away_team                                           -0.002828
# home_team_goal                                       0.016673
# away_team_goal                                      -0.026448
# result                                               0.025184
# home_team year                                      -0.131532
# home_team buildUpPlaySpeed                           0.160171
# home_team buildUpPlayDribbling                      -0.053371
# home_team buildUpPlayPassing                         0.160138
# home_team chanceCreationPassing                      0.182458
# home_team chanceCreationCrossing                     0.084233
# home_team chanceCreationShooting                     0.116424
# home_team defencePressure                            0.434220
# home_team defenceAggression                          1.000000
# home_team defenceTeamWidth                           0.279792
# away_team year                                      -0.120334
# away_team buildUpPlaySpeed                           0.147704
# away_team buildUpPlayDribbling                      -0.025535
# away_team buildUpPlayPassing                         0.173139
# away_team chanceCreationPassing                      0.141771
# away_team chanceCreationCrossing                     0.082966
# away_team chanceCreationShooting                     0.059885
# away_team defencePressure                            0.244167
# away_team defenceAggression                          0.347829
# away_team defenceTeamWidth                           0.204790
#
#                                   home_team defenceTeamWidth  away_team year  \
# Unnamed: 0                                          0.059553        0.104621
# year                                               -0.039786        0.959829
# home_team                                          -0.073971        0.072974
# away_team                                           0.002487        0.082388
# home_team_goal                                      0.027531        0.007472
# away_team_goal                                     -0.023457        0.018994
# result                                              0.027691       -0.018515
# home_team year                                     -0.039828        0.964258
# home_team buildUpPlaySpeed                          0.097492        0.076441
# home_team buildUpPlayDribbling                     -0.012829        0.678326
# home_team buildUpPlayPassing                        0.037293        0.043040
# home_team chanceCreationPassing                     0.133127        0.012123
# home_team chanceCreationCrossing                    0.078072       -0.017790
# home_team chanceCreationShooting                    0.139992       -0.319805
# home_team defencePressure                           0.579072       -0.102762
# home_team defenceAggression                         0.279792       -0.120334
# home_team defenceTeamWidth                          1.000000       -0.033096
# away_team year                                     -0.033096        1.000000
# away_team buildUpPlaySpeed                          0.090351        0.079759
# away_team buildUpPlayDribbling                     -0.026683        0.699644
# away_team buildUpPlayPassing                        0.113812        0.048769
# away_team chanceCreationPassing                     0.062507        0.013378
# away_team chanceCreationCrossing                    0.011244       -0.015426
# away_team chanceCreationShooting                    0.030721       -0.329562
# away_team defencePressure                           0.236695       -0.115707
# away_team defenceAggression                         0.205413       -0.131542
# away_team defenceTeamWidth                          0.288507       -0.039964
#
#                                   away_team buildUpPlaySpeed  \
# Unnamed: 0                                         -0.192950
# year                                                0.069409
# home_team                                           0.016407
# away_team                                           0.058943
# home_team_goal                                      0.001807
# away_team_goal                                      0.005582
# result                                             -0.000353
# home_team year                                      0.076580
# home_team buildUpPlaySpeed                          0.279670
# home_team buildUpPlayDribbling                      0.085575
# home_team buildUpPlayPassing                        0.185863
# home_team chanceCreationPassing                     0.115379
# home_team chanceCreationCrossing                    0.125727
# home_team chanceCreationShooting                   -0.027759
# home_team defencePressure                           0.052763
# home_team defenceAggression                         0.147704
# home_team defenceTeamWidth                          0.090351
# away_team year                                      0.079759
# away_team buildUpPlaySpeed                          1.000000
# away_team buildUpPlayDribbling                      0.100648
# away_team buildUpPlayPassing                        0.425512
# away_team chanceCreationPassing                     0.326365
# away_team chanceCreationCrossing                    0.223352
# away_team chanceCreationShooting                    0.081452
# away_team defencePressure                           0.069473
# away_team defenceAggression                         0.160129
# away_team defenceTeamWidth                          0.097341
#
#                                   away_team buildUpPlayDribbling  \
# Unnamed: 0                                              0.100529
# year                                                    0.639512
# home_team                                               0.071667
# away_team                                               0.116656
# home_team_goal                                         -0.007767
# away_team_goal                                          0.011275
# result                                                 -0.018560
# home_team year                                          0.678391
# home_team buildUpPlaySpeed                              0.085308
# home_team buildUpPlayDribbling                          0.765930
# home_team buildUpPlayPassing                            0.011697
# home_team chanceCreationPassing                         0.010714
# home_team chanceCreationCrossing                       -0.023785
# home_team chanceCreationShooting                       -0.147707
# home_team defencePressure                              -0.051807
# home_team defenceAggression                            -0.025535
# home_team defenceTeamWidth                             -0.026683
# away_team year                                          0.699644
# away_team buildUpPlaySpeed                              0.100648
# away_team buildUpPlayDribbling                          1.000000
# away_team buildUpPlayPassing                            0.008336
# away_team chanceCreationPassing                         0.033673
# away_team chanceCreationCrossing                       -0.002449
# away_team chanceCreationShooting                       -0.132320
# away_team defencePressure                              -0.047246
# away_team defenceAggression                            -0.053312
# away_team defenceTeamWidth                             -0.013094
#
#                                   away_team buildUpPlayPassing  \
# Unnamed: 0                                           -0.109148
# year                                                  0.046991
# home_team                                            -0.001920
# away_team                                             0.016083
# home_team_goal                                        0.031429
# away_team_goal                                       -0.063611
# result                                                0.053070
# home_team year                                        0.043033
# home_team buildUpPlaySpeed                            0.185763
# home_team buildUpPlayDribbling                        0.011320
# home_team buildUpPlayPassing                          0.225467
# home_team chanceCreationPassing                       0.114025
# home_team chanceCreationCrossing                      0.130143
# home_team chanceCreationShooting                     -0.056146
# home_team defencePressure                             0.098717
# home_team defenceAggression                           0.173139
# home_team defenceTeamWidth                            0.113812
# away_team year                                        0.048769
# away_team buildUpPlaySpeed                            0.425512
# away_team buildUpPlayDribbling                        0.008336
# away_team buildUpPlayPassing                          1.000000
# away_team chanceCreationPassing                       0.198085
# away_team chanceCreationCrossing                      0.251428
# away_team chanceCreationShooting                     -0.091953
# away_team defencePressure                            -0.055246
# away_team defenceAggression                           0.160098
# away_team defenceTeamWidth                            0.037297
#
#                                   away_team chanceCreationPassing  \
# Unnamed: 0                                               0.060018
# year                                                     0.013899
# home_team                                               -0.005672
# away_team                                                0.009747
# home_team_goal                                          -0.013738
# away_team_goal                                           0.023558
# result                                                  -0.029135
# home_team year                                           0.012189
# home_team buildUpPlaySpeed                               0.114882
# home_team buildUpPlayDribbling                           0.010837
# home_team buildUpPlayPassing                             0.113880
# home_team chanceCreationPassing                          0.157844
# home_team chanceCreationCrossing                         0.129179
# home_team chanceCreationShooting                        -0.016977
# home_team defencePressure                                0.070001
# home_team defenceAggression                              0.141771
# home_team defenceTeamWidth                               0.062507
# away_team year                                           0.013378
# away_team buildUpPlaySpeed                               0.326365
# away_team buildUpPlayDribbling                           0.033673
# away_team buildUpPlayPassing                             0.198085
# away_team chanceCreationPassing                          1.000000
# away_team chanceCreationCrossing                         0.259453
# away_team chanceCreationShooting                         0.142466
# away_team defencePressure                                0.200752
# away_team defenceAggression                              0.182558
# away_team defenceTeamWidth                               0.132934
#
#                                   away_team chanceCreationCrossing  \
# Unnamed: 0                                               -0.011622
# year                                                     -0.014905
# home_team                                                 0.013467
# away_team                                                -0.014578
# home_team_goal                                           -0.016635
# away_team_goal                                            0.008814
# result                                                   -0.020362
# home_team year                                           -0.017995
# home_team buildUpPlaySpeed                                0.126045
# home_team buildUpPlayDribbling                           -0.023898
# home_team buildUpPlayPassing                              0.130236
# home_team chanceCreationPassing                           0.129378
# home_team chanceCreationCrossing                          0.178711
# home_team chanceCreationShooting                         -0.035703
# home_team defencePressure                                -0.008857
# home_team defenceAggression                               0.082966
# home_team defenceTeamWidth                                0.011244
# away_team year                                           -0.015426
# away_team buildUpPlaySpeed                                0.223352
# away_team buildUpPlayDribbling                           -0.002449
# away_team buildUpPlayPassing                              0.251428
# away_team chanceCreationPassing                           0.259453
# away_team chanceCreationCrossing                          1.000000
# away_team chanceCreationShooting                         -0.017738
# away_team defencePressure                                 0.029424
# away_team defenceAggression                               0.084344
# away_team defenceTeamWidth                                0.078075
#
#                                   away_team chanceCreationShooting  \
# Unnamed: 0                                                0.076765
# year                                                     -0.339565
# home_team                                                -0.029240
# away_team                                                -0.055745
# home_team_goal                                           -0.033569
# away_team_goal                                            0.020656
# result                                                   -0.024512
# home_team year                                           -0.319645
# home_team buildUpPlaySpeed                               -0.028116
# home_team buildUpPlayDribbling                           -0.147523
# home_team buildUpPlayPassing                             -0.056545
# home_team chanceCreationPassing                          -0.017056
# home_team chanceCreationCrossing                         -0.034985
# home_team chanceCreationShooting                          0.214471
# home_team defencePressure                                 0.056726
# home_team defenceAggression                               0.059885
# home_team defenceTeamWidth                                0.030721
# away_team year                                           -0.329562
# away_team buildUpPlaySpeed                                0.081452
# away_team buildUpPlayDribbling                           -0.132320
# away_team buildUpPlayPassing                             -0.091953
# away_team chanceCreationPassing                           0.142466
# away_team chanceCreationCrossing                         -0.017738
# away_team chanceCreationShooting                          1.000000
# away_team defencePressure                                 0.209951
# away_team defenceAggression                               0.116495
# away_team defenceTeamWidth                                0.139780
#
#                                   away_team defencePressure  \
# Unnamed: 0                                        -0.025416
# year                                              -0.122268
# home_team                                         -0.021945
# away_team                                         -0.065193
# home_team_goal                                    -0.043193
# away_team_goal                                     0.059548
# result                                            -0.063262
# home_team year                                    -0.102874
# home_team buildUpPlaySpeed                         0.052631
# home_team buildUpPlayDribbling                    -0.051699
# home_team buildUpPlayPassing                       0.098418
# home_team chanceCreationPassing                    0.070390
# home_team chanceCreationCrossing                  -0.009225
# home_team chanceCreationShooting                   0.056098
# home_team defencePressure                          0.273275
# home_team defenceAggression                        0.244167
# home_team defenceTeamWidth                         0.236695
# away_team year                                    -0.115707
# away_team buildUpPlaySpeed                         0.069473
# away_team buildUpPlayDribbling                    -0.047246
# away_team buildUpPlayPassing                      -0.055246
# away_team chanceCreationPassing                    0.200752
# away_team chanceCreationCrossing                   0.029424
# away_team chanceCreationShooting                   0.209951
# away_team defencePressure                          1.000000
# away_team defenceAggression                        0.434356
# away_team defenceTeamWidth                         0.578865
#
#                                   away_team defenceAggression  \
# Unnamed: 0                                          -0.130085
# year                                                -0.144935
# home_team                                           -0.002843
# away_team                                           -0.033087
# home_team_goal                                      -0.027612
# away_team_goal                                       0.016318
# result                                              -0.023084
# home_team year                                      -0.120351
# home_team buildUpPlaySpeed                           0.147713
# home_team buildUpPlayDribbling                      -0.025192
# home_team buildUpPlayPassing                         0.173618
# home_team chanceCreationPassing                      0.141900
# home_team chanceCreationCrossing                     0.083525
# home_team chanceCreationShooting                     0.059727
# home_team defencePressure                            0.244445
# home_team defenceAggression                          0.347829
# home_team defenceTeamWidth                           0.205413
# away_team year                                      -0.131542
# away_team buildUpPlaySpeed                           0.160129
# away_team buildUpPlayDribbling                      -0.053312
# away_team buildUpPlayPassing                         0.160098
# away_team chanceCreationPassing                      0.182558
# away_team chanceCreationCrossing                     0.084344
# away_team chanceCreationShooting                     0.116495
# away_team defencePressure                            0.434356
# away_team defenceAggression                          1.000000
# away_team defenceTeamWidth                           0.279747
#
#                                   away_team defenceTeamWidth
# Unnamed: 0                                          0.059499
# year                                               -0.039935
# home_team                                           0.002523
# away_team                                          -0.073971
# home_team_goal                                     -0.023357
# away_team_goal                                      0.025729
# result                                             -0.030304
# home_team year                                     -0.033280
# home_team buildUpPlaySpeed                          0.090506
# home_team buildUpPlayDribbling                     -0.027124
# home_team buildUpPlayPassing                        0.113278
# home_team chanceCreationPassing                     0.062265
# home_team chanceCreationCrossing                    0.010853
# home_team chanceCreationShooting                    0.029617
# home_team defencePressure                           0.236314
# home_team defenceAggression                         0.204790
# home_team defenceTeamWidth                          0.288507
# away_team year                                     -0.039964
# away_team buildUpPlaySpeed                          0.097341
# away_team buildUpPlayDribbling                     -0.013094
# away_team buildUpPlayPassing                        0.037297
# away_team chanceCreationPassing                     0.132934
# away_team chanceCreationCrossing                    0.078075
# away_team chanceCreationShooting                    0.139780
# away_team defencePressure                           0.578865
# away_team defenceAggression                         0.279747
# away_team defenceTeamWidth                          1.000000

# %%
t_X,val_X,t_y,val_y=train_test_split(X,y,test_size=0.2)
train_X,test_X,train_y,test_y=train_test_split(t_X,t_y,test_size=0.2)

# %%
print("TRAIN: ",len(train_X),"    ",len(train_y))
print("TEST: ",len(test_X),"    ",len(test_y))
print("VALIDATION: ",len(val_X),"    ",len(val_y))
# Out:
# TRAIN:  16421      16421
# TEST:  4106      4106
# VALIDATION:  5132      5132

# %%
rf = RandomForestClassifier(n_estimators=200)
rf.fit(train_X, train_y)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
y_pred=rf.predict(test_X)
score = accuracy_score(test_y,y_pred)

print("RANDOM FOREST 200 trees:   " ,score)
# Out:
# RANDOM FOREST 200 trees:    0.4529956161714564

# %%
y_valpreds = rf.predict(val_X)
val_score = accuracy_score(val_y,y_valpreds)
val_score
# Out:
# 0.4524551831644583

# %%
print("RANDOM FOREST 200 trees:   " ,score)
print("VALIDATION SCORE:  ",val_score)
# Out:
# RANDOM FOREST 200 trees:    0.4529956161714564
# VALIDATION SCORE:   0.4524551831644583

# %%
ada=AdaBoostClassifier(n_estimators=80)
ada.fit(train_X, train_y)
# Out:
# AdaBoostClassifier(n_estimators=80)

# %%
y_pred_ada=ada.predict(test_X)
score_ada=accuracy_score(test_y,y_pred_ada)
score_ada
# Out:
# 0.4873356064296152

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
y_pred_gnb = gnb.fit(train_X, train_y).predict(test_X)
score_gnb=accuracy_score(test_y,y_pred_gnb)
score_gnb
# Out:
# 0.46054554310764734

# %%
from sklearn.neural_network import MLPClassifier
clf = MLPClassifier(random_state=1, max_iter=300).fit(train_X, train_y)
clf.score(test_X, test_y)
# Out:
# 0.47320993667803213
