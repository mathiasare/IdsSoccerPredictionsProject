# %% [markdown]
# # NOTEBOOK FOR DATA PREPARATION FOR MODEL A
#
# ## AUTHOR: MATHIAS ARE

# %%
#Imports
import numpy as np
import pandas as pd

# %%
#Read data in

matches = pd.read_csv("./data/match.csv")
players = pd.read_csv("./data/player.csv")
player_attributes = pd.read_csv("./data/player_attributes.csv")
len(matches)
# Out:
# 25979

# %%
#Dropping unused columns
mat=matches.drop(columns=matches.columns[11:55])
ma = mat.drop(columns=mat.columns[33:])
ma=ma.drop(columns=ma.columns[1:9])

#Replacing goal scores with result column
# 1 = home_team_win, 0 = tie, -1 = away_team_win


ma["result"]=ma["home_team_goal"] - ma["away_team_goal"]
ma.loc[ma["result"]>0,"result"] = 1
ma.loc[ma["result"]<0,"result"] = -1
ma.loc[ma["result"]==0,"result"] = 0
ma.drop(columns=["home_team_goal","away_team_goal"])

#Remove na values
ma=ma.dropna()

#Remove na values and unused columns from player attributes dataframe
pa = player_attributes.dropna()
pa = pa[['id','overall_rating']]
print(len(ma))

#Show na values for each column of matches tabel to check if everything is correct
for i, sum in enumerate(ma.isna().sum()):
    print(ma.columns[i]+"\t"*4,sum)
# Out:
# 21374
# id				 0
# home_team_goal				 0
# away_team_goal				 0
# home_player_1				 0
# home_player_2				 0
# home_player_3				 0
# home_player_4				 0
# home_player_5				 0
# home_player_6				 0
# home_player_7				 0
# home_player_8				 0
# home_player_9				 0
# home_player_10				 0
# home_player_11				 0
# away_player_1				 0
# away_player_2				 0
# away_player_3				 0
# away_player_4				 0
# away_player_5				 0
# away_player_6				 0
# away_player_7				 0
# away_player_8				 0
# away_player_9				 0
# away_player_10				 0
# away_player_11				 0
# result				 0

# %%
#Result distribution

ma.groupby("result")["id"].count()
# Out:
# result
# -1    6166
#  0    5398
#  1    9810
# Name: id, dtype: int64

# %%
#Find average values for each column in pa and save to dictionary

averages=dict()
pa = pa.select_dtypes(exclude=['object'])
pa=pa.drop(columns=["player_fifa_api_id","player_api_id"])
for col in pa.columns:
    averages[col]=((pa[col].mean()*100).round())/100

#Print results
for key in averages.keys():
    print(key + "    ",averages[key])
# Out:
# id     91995.89
# overall_rating     68.64

# %%
#Merge first players attributes to the matches table.

new_df=pd.merge(ma,pa,left_on="home_player_1",right_on="id",how="left").drop(columns=["id_y"])
new_df["id"]=new_df["id_x"]
new_df=new_df.drop(columns=["id_x"])
for col in pa.columns[1:]:
    new_df["home_player_1 "+col]=new_df[col]
    new_df=new_df.drop(columns=[col])

#Merge rest of the players attributes to the matches table

for j in range(2,23):
    s= "home_player_" if j<12 else "away_player_"
    k = j if j<12 else j-11
    new_df=pd.merge(new_df,pa,left_on=(s+str(k)),right_on="id",how="left").drop(columns=["id_y"])
    new_df["id"]=new_df["id_x"]
    new_df=new_df.drop(columns=["id_x"])
    for col in pa.columns[1:]:
        new_df[s+str(k)+" "+col]=new_df[col]
        new_df=new_df.drop(columns=[col])



#Check for na values
for i, sum in enumerate(new_df.isna().sum()):
    print(new_df.columns[i]+"\t"*4,sum)
# Out:
# home_team_goal				 0
# away_team_goal				 0
# home_player_1				 0
# home_player_2				 0
# home_player_3				 0
# home_player_4				 0
# home_player_5				 0
# home_player_6				 0
# home_player_7				 0
# home_player_8				 0
# home_player_9				 0
# home_player_10				 0
# home_player_11				 0
# away_player_1				 0
# away_player_2				 0
# away_player_3				 0
# away_player_4				 0
# away_player_5				 0
# away_player_6				 0
# away_player_7				 0
# away_player_8				 0
# away_player_9				 0
# away_player_10				 0
# away_player_11				 0
# result				 0
# home_player_1 overall_rating				 2590
# home_player_2 overall_rating				 4460
# home_player_3 overall_rating				 3686
# home_player_4 overall_rating				 3773
# home_player_5 overall_rating				 4686
# home_player_6 overall_rating				 4231
# home_player_7 overall_rating				 3829
# home_player_8 overall_rating				 4468
# home_player_9 overall_rating				 4677
# home_player_10 overall_rating				 4396
# home_player_11 overall_rating				 4180
# away_player_1 overall_rating				 2607
# away_player_2 overall_rating				 4444
# away_player_3 overall_rating				 3659
# away_player_4 overall_rating				 3764
# away_player_5 overall_rating				 4684
# away_player_6 overall_rating				 4216
# away_player_7 overall_rating				 3837
# away_player_8 overall_rating				 4586
# away_player_9 overall_rating				 4682
# away_player_10 overall_rating				 4450
# id				 0
# away_player_11 overall_rating				 4297

# %%
#Fill na values with average values from dictionary

for col in new_df.columns:
    splitter=col.split(' ')
    if(len(splitter)>1):
        original_name=splitter[1]
        print(averages[original_name])
        new_df[col]=new_df[col].fillna(averages[original_name])
# Out:
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64
# 68.64

# %%
#Check again for na values (there should not be any)

for i, sum in enumerate(new_df.isna().sum()):
    print(new_df.columns[i]+"\t"*4,sum)
# Out:
# home_team_goal				 0
# away_team_goal				 0
# home_player_1				 0
# home_player_2				 0
# home_player_3				 0
# home_player_4				 0
# home_player_5				 0
# home_player_6				 0
# home_player_7				 0
# home_player_8				 0
# home_player_9				 0
# home_player_10				 0
# home_player_11				 0
# away_player_1				 0
# away_player_2				 0
# away_player_3				 0
# away_player_4				 0
# away_player_5				 0
# away_player_6				 0
# away_player_7				 0
# away_player_8				 0
# away_player_9				 0
# away_player_10				 0
# away_player_11				 0
# result				 0
# home_player_1 overall_rating				 0
# home_player_2 overall_rating				 0
# home_player_3 overall_rating				 0
# home_player_4 overall_rating				 0
# home_player_5 overall_rating				 0
# home_player_6 overall_rating				 0
# home_player_7 overall_rating				 0
# home_player_8 overall_rating				 0
# home_player_9 overall_rating				 0
# home_player_10 overall_rating				 0
# home_player_11 overall_rating				 0
# away_player_1 overall_rating				 0
# away_player_2 overall_rating				 0
# away_player_3 overall_rating				 0
# away_player_4 overall_rating				 0
# away_player_5 overall_rating				 0
# away_player_6 overall_rating				 0
# away_player_7 overall_rating				 0
# away_player_8 overall_rating				 0
# away_player_9 overall_rating				 0
# away_player_10 overall_rating				 0
# id				 0
# away_player_11 overall_rating				 0

# %%
#Save dataframe to csv


new_df.to_csv("./data/data2.csv")

new_df

# %%
#Alternate version to merge dataframes
def append_player_attributes(df_m,df_p):
    first = True
    
    colsList=[]
    new_df=None
    for i in range(len(df_m)):
        hasNull=False
        row = df_m.iloc[i]
        row["result"]=convert_result(row)
        row=row.drop(labels=["home_team_goal","away_team_goal"])

        for j in range(1,23):

            s= "home_player_" if j<12 else "away_player_"

            k = j if j<12 else j-11

            Id = row[s+str(k)]

            cols = df_p.columns
            valuesCol = df_p.loc[df_p["id"]==Id].values
            if(len(valuesCol)==0):
                hasNull=True
                continue
            values=list(valuesCol[0])
            for i,col in enumerate(cols):
                row[s+str(k)+"_"+col]=values[i]
        if(first):
            first = False
            new_df=pd.DataFrame(columns=row.keys())
        if(not(hasNull)):
            new_df=new_df.append(row,ignore_index=True)
    return new_df
        






res = append_player_attributes(matches[matches["league_id"] == 1729],pa)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-109-4ad608c3672a> in <module>
#      44
#      45
# ---> 46 res = append_player_attributes(matches[matches["league_id"] == 1729],pa)
#
# <ipython-input-109-4ad608c3672a> in append_player_attributes(df_m, df_p)
#      24
#      25             cols = df_p.columns
# ---> 26             valuesCol = df_p.loc[df_p["id"]==Id].values
#      27             if(len(valuesCol)==0):
#      28                 hasNull=True
#
# ~\miniconda3\envs\Py3_ICNS\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\miniconda3\envs\Py3_ICNS\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     368         rvalues = extract_array(other, extract_numpy=True)
#     369
# --> 370         res_values = comparison_op(lvalues, rvalues, op)
#     371
#     372         return self._construct_result(res_values, name=res_name)
#
# ~\miniconda3\envs\Py3_ICNS\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     244             warnings.simplefilter("ignore", DeprecationWarning)
#     245             with np.errstate(all="ignore"):
# --> 246                 res_values = na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#     247
#     248     return res_values
#
# ~\miniconda3\envs\Py3_ICNS\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     140
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#     144         if is_cmp:
#
# ~\miniconda3\envs\Py3_ICNS\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     228         use_numexpr = use_numexpr and _bool_arith_check(op_str, a, b)
#     229         if use_numexpr:
# --> 230             return _evaluate(op, op_str, a, b)  # type: ignore
#     231     return _evaluate_standard(op, op_str, a, b)
#     232
#
# ~\miniconda3\envs\Py3_ICNS\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      66         _store_test_result(False)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#      70
#
# KeyboardInterrupt:

# %%
#Check for na values
for i, sum in enumerate(res.isna().sum()):
    print(res.columns[i]+"\t"*4,sum)
# Out:
# id				 0
# country_id				 0
# league_id				 0
# season				 0
# stage				 0
# date				 0
# match_api_id				 0
# home_team_api_id				 0
# away_team_api_id				 0
# home_player_X1				 0
# home_player_X2				 0
# home_player_X3				 0
# home_player_X4				 0
# home_player_X5				 0
# home_player_X6				 0
# home_player_X7				 0
# home_player_X8				 0
# home_player_X9				 0
# home_player_X10				 0
# home_player_X11				 0
# away_player_X1				 0
# away_player_X2				 0
# away_player_X3				 0
# away_player_X4				 0
# away_player_X5				 0
# away_player_X6				 0
# away_player_X7				 0
# away_player_X8				 0
# away_player_X9				 0
# away_player_X10				 0
# away_player_X11				 0
# home_player_Y1				 0
# home_player_Y2				 0
# home_player_Y3				 0
# home_player_Y4				 0
# home_player_Y5				 0
# home_player_Y6				 0
# home_player_Y7				 0
# home_player_Y8				 0
# home_player_Y9				 0
# home_player_Y10				 0
# home_player_Y11				 0
# away_player_Y1				 0
# away_player_Y2				 0
# away_player_Y3				 0
# away_player_Y4				 0
# away_player_Y5				 0
# away_player_Y6				 0
# away_player_Y7				 0
# away_player_Y8				 0
# away_player_Y9				 0
# away_player_Y10				 0
# away_player_Y11				 0
# home_player_1				 0
# home_player_2				 0
# home_player_3				 0
# home_player_4				 0
# home_player_5				 0
# home_player_6				 0
# home_player_7				 0
# home_player_8				 0
# home_player_9				 0
# home_player_10				 0
# home_player_11				 0
# away_player_1				 0
# away_player_2				 0
# away_player_3				 0
# away_player_4				 0
# away_player_5				 0
# away_player_6				 0
# away_player_7				 0
# away_player_8				 0
# away_player_9				 0
# away_player_10				 0
# away_player_11				 0
# goal				 0
# shoton				 0
# shotoff				 0
# foulcommit				 0
# card				 0
# cross				 0
# corner				 0
# possession				 0
# B365H				 0
# B365D				 0
# B365A				 0
# BWH				 0
# BWD				 0
# BWA				 0
# IWH				 0
# IWD				 0
# IWA				 0
# LBH				 0
# LBD				 0
# LBA				 0
# PSH				 0
# PSD				 0
# PSA				 0
# WHH				 0
# WHD				 0
# WHA				 0
# SJH				 0
# SJD				 0
# SJA				 0
# VCH				 0
# VCD				 0
# VCA				 0
# GBH				 0
# GBD				 0
# GBA				 0
# BSH				 0
# BSD				 0
# BSA				 0
# result				 0
# home_player_1_id				 0
# home_player_1_player_fifa_api_id				 0
# home_player_1_player_api_id				 0
# home_player_1_date				 0
# home_player_1_overall_rating				 0
# home_player_1_potential				 0
# home_player_1_preferred_foot				 0
# home_player_1_attacking_work_rate				 0
# home_player_1_defensive_work_rate				 0
# home_player_1_crossing				 0
# home_player_1_finishing				 0
# home_player_1_heading_accuracy				 0
# home_player_1_short_passing				 0
# home_player_1_volleys				 0
# home_player_1_dribbling				 0
# home_player_1_curve				 0
# home_player_1_free_kick_accuracy				 0
# home_player_1_long_passing				 0
# home_player_1_ball_control				 0
# home_player_1_acceleration				 0
# home_player_1_sprint_speed				 0
# home_player_1_agility				 0
# home_player_1_reactions				 0
# home_player_1_balance				 0
# home_player_1_shot_power				 0
# home_player_1_jumping				 0
# home_player_1_stamina				 0
# home_player_1_strength				 0
# home_player_1_long_shots				 0
# home_player_1_aggression				 0
# home_player_1_interceptions				 0
# home_player_1_positioning				 0
# home_player_1_vision				 0
# home_player_1_penalties				 0
# home_player_1_marking				 0
# home_player_1_standing_tackle				 0
# home_player_1_sliding_tackle				 0
# home_player_1_gk_diving				 0
# home_player_1_gk_handling				 0
# home_player_1_gk_kicking				 0
# home_player_1_gk_positioning				 0
# home_player_1_gk_reflexes				 0
# home_player_4_id				 0
# home_player_4_player_fifa_api_id				 0
# home_player_4_player_api_id				 0
# home_player_4_date				 0
# home_player_4_overall_rating				 0
# home_player_4_potential				 0
# home_player_4_preferred_foot				 0
# home_player_4_attacking_work_rate				 0
# home_player_4_defensive_work_rate				 0
# home_player_4_crossing				 0
# home_player_4_finishing				 0
# home_player_4_heading_accuracy				 0
# home_player_4_short_passing				 0
# home_player_4_volleys				 0
# home_player_4_dribbling				 0
# home_player_4_curve				 0
# home_player_4_free_kick_accuracy				 0
# home_player_4_long_passing				 0
# home_player_4_ball_control				 0
# home_player_4_acceleration				 0
# home_player_4_sprint_speed				 0
# home_player_4_agility				 0
# home_player_4_reactions				 0
# home_player_4_balance				 0
# home_player_4_shot_power				 0
# home_player_4_jumping				 0
# home_player_4_stamina				 0
# home_player_4_strength				 0
# home_player_4_long_shots				 0
# home_player_4_aggression				 0
# home_player_4_interceptions				 0
# home_player_4_positioning				 0
# home_player_4_vision				 0
# home_player_4_penalties				 0
# home_player_4_marking				 0
# home_player_4_standing_tackle				 0
# home_player_4_sliding_tackle				 0
# home_player_4_gk_diving				 0
# home_player_4_gk_handling				 0
# home_player_4_gk_kicking				 0
# home_player_4_gk_positioning				 0
# home_player_4_gk_reflexes				 0
# home_player_5_id				 0
# home_player_5_player_fifa_api_id				 0
# home_player_5_player_api_id				 0
# home_player_5_date				 0
# home_player_5_overall_rating				 0
# home_player_5_potential				 0
# home_player_5_preferred_foot				 0
# home_player_5_attacking_work_rate				 0
# home_player_5_defensive_work_rate				 0
# home_player_5_crossing				 0
# home_player_5_finishing				 0
# home_player_5_heading_accuracy				 0
# home_player_5_short_passing				 0
# home_player_5_volleys				 0
# home_player_5_dribbling				 0
# home_player_5_curve				 0
# home_player_5_free_kick_accuracy				 0
# home_player_5_long_passing				 0
# home_player_5_ball_control				 0
# home_player_5_acceleration				 0
# home_player_5_sprint_speed				 0
# home_player_5_agility				 0
# home_player_5_reactions				 0
# home_player_5_balance				 0
# home_player_5_shot_power				 0
# home_player_5_jumping				 0
# home_player_5_stamina				 0
# home_player_5_strength				 0
# home_player_5_long_shots				 0
# home_player_5_aggression				 0
# home_player_5_interceptions				 0
# home_player_5_positioning				 0
# home_player_5_vision				 0
# home_player_5_penalties				 0
# home_player_5_marking				 0
# home_player_5_standing_tackle				 0
# home_player_5_sliding_tackle				 0
# home_player_5_gk_diving				 0
# home_player_5_gk_handling				 0
# home_player_5_gk_kicking				 0
# home_player_5_gk_positioning				 0
# home_player_5_gk_reflexes				 0
# home_player_6_id				 0
# home_player_6_player_fifa_api_id				 0
# home_player_6_player_api_id				 0
# home_player_6_date				 0
# home_player_6_overall_rating				 0
# home_player_6_potential				 0
# home_player_6_preferred_foot				 0
# home_player_6_attacking_work_rate				 0
# home_player_6_defensive_work_rate				 0
# home_player_6_crossing				 0
# home_player_6_finishing				 0
# home_player_6_heading_accuracy				 0
# home_player_6_short_passing				 0
# home_player_6_volleys				 0
# home_player_6_dribbling				 0
# home_player_6_curve				 0
# home_player_6_free_kick_accuracy				 0
# home_player_6_long_passing				 0
# home_player_6_ball_control				 0
# home_player_6_acceleration				 0
# home_player_6_sprint_speed				 0
# home_player_6_agility				 0
# home_player_6_reactions				 0
# home_player_6_balance				 0
# home_player_6_shot_power				 0
# home_player_6_jumping				 0
# home_player_6_stamina				 0
# home_player_6_strength				 0
# home_player_6_long_shots				 0
# home_player_6_aggression				 0
# home_player_6_interceptions				 0
# home_player_6_positioning				 0
# home_player_6_vision				 0
# home_player_6_penalties				 0
# home_player_6_marking				 0
# home_player_6_standing_tackle				 0
# home_player_6_sliding_tackle				 0
# home_player_6_gk_diving				 0
# home_player_6_gk_handling				 0
# home_player_6_gk_kicking				 0
# home_player_6_gk_positioning				 0
# home_player_6_gk_reflexes				 0
# home_player_8_id				 0
# home_player_8_player_fifa_api_id				 0
# home_player_8_player_api_id				 0
# home_player_8_date				 0
# home_player_8_overall_rating				 0
# home_player_8_potential				 0
# home_player_8_preferred_foot				 0
# home_player_8_attacking_work_rate				 0
# home_player_8_defensive_work_rate				 0
# home_player_8_crossing				 0
# home_player_8_finishing				 0
# home_player_8_heading_accuracy				 0
# home_player_8_short_passing				 0
# home_player_8_volleys				 0
# home_player_8_dribbling				 0
# home_player_8_curve				 0
# home_player_8_free_kick_accuracy				 0
# home_player_8_long_passing				 0
# home_player_8_ball_control				 0
# home_player_8_acceleration				 0
# home_player_8_sprint_speed				 0
# home_player_8_agility				 0
# home_player_8_reactions				 0
# home_player_8_balance				 0
# home_player_8_shot_power				 0
# home_player_8_jumping				 0
# home_player_8_stamina				 0
# home_player_8_strength				 0
# home_player_8_long_shots				 0
# home_player_8_aggression				 0
# home_player_8_interceptions				 0
# home_player_8_positioning				 0
# home_player_8_vision				 0
# home_player_8_penalties				 0
# home_player_8_marking				 0
# home_player_8_standing_tackle				 0
# home_player_8_sliding_tackle				 0
# home_player_8_gk_diving				 0
# home_player_8_gk_handling				 0
# home_player_8_gk_kicking				 0
# home_player_8_gk_positioning				 0
# home_player_8_gk_reflexes				 0
# home_player_9_id				 0
# home_player_9_player_fifa_api_id				 0
# home_player_9_player_api_id				 0
# home_player_9_date				 0
# home_player_9_overall_rating				 0
# home_player_9_potential				 0
# home_player_9_preferred_foot				 0
# home_player_9_attacking_work_rate				 0
# home_player_9_defensive_work_rate				 0
# home_player_9_crossing				 0
# home_player_9_finishing				 0
# home_player_9_heading_accuracy				 0
# home_player_9_short_passing				 0
# home_player_9_volleys				 0
# home_player_9_dribbling				 0
# home_player_9_curve				 0
# home_player_9_free_kick_accuracy				 0
# home_player_9_long_passing				 0
# home_player_9_ball_control				 0
# home_player_9_acceleration				 0
# home_player_9_sprint_speed				 0
# home_player_9_agility				 0
# home_player_9_reactions				 0
# home_player_9_balance				 0
# home_player_9_shot_power				 0
# home_player_9_jumping				 0
# home_player_9_stamina				 0
# home_player_9_strength				 0
# home_player_9_long_shots				 0
# home_player_9_aggression				 0
# home_player_9_interceptions				 0
# home_player_9_positioning				 0
# home_player_9_vision				 0
# home_player_9_penalties				 0
# home_player_9_marking				 0
# home_player_9_standing_tackle				 0
# home_player_9_sliding_tackle				 0
# home_player_9_gk_diving				 0
# home_player_9_gk_handling				 0
# home_player_9_gk_kicking				 0
# home_player_9_gk_positioning				 0
# home_player_9_gk_reflexes				 0
# home_player_10_id				 0
# home_player_10_player_fifa_api_id				 0
# home_player_10_player_api_id				 0
# home_player_10_date				 0
# home_player_10_overall_rating				 0
# home_player_10_potential				 0
# home_player_10_preferred_foot				 0
# home_player_10_attacking_work_rate				 0
# home_player_10_defensive_work_rate				 0
# home_player_10_crossing				 0
# home_player_10_finishing				 0
# home_player_10_heading_accuracy				 0
# home_player_10_short_passing				 0
# home_player_10_volleys				 0
# home_player_10_dribbling				 0
# home_player_10_curve				 0
# home_player_10_free_kick_accuracy				 0
# home_player_10_long_passing				 0
# home_player_10_ball_control				 0
# home_player_10_acceleration				 0
# home_player_10_sprint_speed				 0
# home_player_10_agility				 0
# home_player_10_reactions				 0
# home_player_10_balance				 0
# home_player_10_shot_power				 0
# home_player_10_jumping				 0
# home_player_10_stamina				 0
# home_player_10_strength				 0
# home_player_10_long_shots				 0
# home_player_10_aggression				 0
# home_player_10_interceptions				 0
# home_player_10_positioning				 0
# home_player_10_vision				 0
# home_player_10_penalties				 0
# home_player_10_marking				 0
# home_player_10_standing_tackle				 0
# home_player_10_sliding_tackle				 0
# home_player_10_gk_diving				 0
# home_player_10_gk_handling				 0
# home_player_10_gk_kicking				 0
# home_player_10_gk_positioning				 0
# home_player_10_gk_reflexes				 0
# home_player_11_id				 0
# home_player_11_player_fifa_api_id				 0
# home_player_11_player_api_id				 0
# home_player_11_date				 0
# home_player_11_overall_rating				 0
# home_player_11_potential				 0
# home_player_11_preferred_foot				 0
# home_player_11_attacking_work_rate				 0
# home_player_11_defensive_work_rate				 0
# home_player_11_crossing				 0
# home_player_11_finishing				 0
# home_player_11_heading_accuracy				 0
# home_player_11_short_passing				 0
# home_player_11_volleys				 0
# home_player_11_dribbling				 0
# home_player_11_curve				 0
# home_player_11_free_kick_accuracy				 0
# home_player_11_long_passing				 0
# home_player_11_ball_control				 0
# home_player_11_acceleration				 0
# home_player_11_sprint_speed				 0
# home_player_11_agility				 0
# home_player_11_reactions				 0
# home_player_11_balance				 0
# home_player_11_shot_power				 0
# home_player_11_jumping				 0
# home_player_11_stamina				 0
# home_player_11_strength				 0
# home_player_11_long_shots				 0
# home_player_11_aggression				 0
# home_player_11_interceptions				 0
# home_player_11_positioning				 0
# home_player_11_vision				 0
# home_player_11_penalties				 0
# home_player_11_marking				 0
# home_player_11_standing_tackle				 0
# home_player_11_sliding_tackle				 0
# home_player_11_gk_diving				 0
# home_player_11_gk_handling				 0
# home_player_11_gk_kicking				 0
# home_player_11_gk_positioning				 0
# home_player_11_gk_reflexes				 0
# away_player_1_id				 0
# away_player_1_player_fifa_api_id				 0
# away_player_1_player_api_id				 0
# away_player_1_date				 0
# away_player_1_overall_rating				 0
# away_player_1_potential				 0
# away_player_1_preferred_foot				 0
# away_player_1_attacking_work_rate				 0
# away_player_1_defensive_work_rate				 0
# away_player_1_crossing				 0
# away_player_1_finishing				 0
# away_player_1_heading_accuracy				 0
# away_player_1_short_passing				 0
# away_player_1_volleys				 0
# away_player_1_dribbling				 0
# away_player_1_curve				 0
# away_player_1_free_kick_accuracy				 0
# away_player_1_long_passing				 0
# away_player_1_ball_control				 0
# away_player_1_acceleration				 0
# away_player_1_sprint_speed				 0
# away_player_1_agility				 0
# away_player_1_reactions				 0
# away_player_1_balance				 0
# away_player_1_shot_power				 0
# away_player_1_jumping				 0
# away_player_1_stamina				 0
# away_player_1_strength				 0
# away_player_1_long_shots				 0
# away_player_1_aggression				 0
# away_player_1_interceptions				 0
# away_player_1_positioning				 0
# away_player_1_vision				 0
# away_player_1_penalties				 0
# away_player_1_marking				 0
# away_player_1_standing_tackle				 0
# away_player_1_sliding_tackle				 0
# away_player_1_gk_diving				 0
# away_player_1_gk_handling				 0
# away_player_1_gk_kicking				 0
# away_player_1_gk_positioning				 0
# away_player_1_gk_reflexes				 0
# away_player_3_id				 0
# away_player_3_player_fifa_api_id				 0
# away_player_3_player_api_id				 0
# away_player_3_date				 0
# away_player_3_overall_rating				 0
# away_player_3_potential				 0
# away_player_3_preferred_foot				 0
# away_player_3_attacking_work_rate				 0
# away_player_3_defensive_work_rate				 0
# away_player_3_crossing				 0
# away_player_3_finishing				 0
# away_player_3_heading_accuracy				 0
# away_player_3_short_passing				 0
# away_player_3_volleys				 0
# away_player_3_dribbling				 0
# away_player_3_curve				 0
# away_player_3_free_kick_accuracy				 0
# away_player_3_long_passing				 0
# away_player_3_ball_control				 0
# away_player_3_acceleration				 0
# away_player_3_sprint_speed				 0
# away_player_3_agility				 0
# away_player_3_reactions				 0
# away_player_3_balance				 0
# away_player_3_shot_power				 0
# away_player_3_jumping				 0
# away_player_3_stamina				 0
# away_player_3_strength				 0
# away_player_3_long_shots				 0
# away_player_3_aggression				 0
# away_player_3_interceptions				 0
# away_player_3_positioning				 0
# away_player_3_vision				 0
# away_player_3_penalties				 0
# away_player_3_marking				 0
# away_player_3_standing_tackle				 0
# away_player_3_sliding_tackle				 0
# away_player_3_gk_diving				 0
# away_player_3_gk_handling				 0
# away_player_3_gk_kicking				 0
# away_player_3_gk_positioning				 0
# away_player_3_gk_reflexes				 0
# away_player_4_id				 0
# away_player_4_player_fifa_api_id				 0
# away_player_4_player_api_id				 0
# away_player_4_date				 0
# away_player_4_overall_rating				 0
# away_player_4_potential				 0
# away_player_4_preferred_foot				 0
# away_player_4_attacking_work_rate				 0
# away_player_4_defensive_work_rate				 0
# away_player_4_crossing				 0
# away_player_4_finishing				 0
# away_player_4_heading_accuracy				 0
# away_player_4_short_passing				 0
# away_player_4_volleys				 0
# away_player_4_dribbling				 0
# away_player_4_curve				 0
# away_player_4_free_kick_accuracy				 0
# away_player_4_long_passing				 0
# away_player_4_ball_control				 0
# away_player_4_acceleration				 0
# away_player_4_sprint_speed				 0
# away_player_4_agility				 0
# away_player_4_reactions				 0
# away_player_4_balance				 0
# away_player_4_shot_power				 0
# away_player_4_jumping				 0
# away_player_4_stamina				 0
# away_player_4_strength				 0
# away_player_4_long_shots				 0
# away_player_4_aggression				 0
# away_player_4_interceptions				 0
# away_player_4_positioning				 0
# away_player_4_vision				 0
# away_player_4_penalties				 0
# away_player_4_marking				 0
# away_player_4_standing_tackle				 0
# away_player_4_sliding_tackle				 0
# away_player_4_gk_diving				 0
# away_player_4_gk_handling				 0
# away_player_4_gk_kicking				 0
# away_player_4_gk_positioning				 0
# away_player_4_gk_reflexes				 0
# away_player_5_id				 0
# away_player_5_player_fifa_api_id				 0
# away_player_5_player_api_id				 0
# away_player_5_date				 0
# away_player_5_overall_rating				 0
# away_player_5_potential				 0
# away_player_5_preferred_foot				 0
# away_player_5_attacking_work_rate				 0
# away_player_5_defensive_work_rate				 0
# away_player_5_crossing				 0
# away_player_5_finishing				 0
# away_player_5_heading_accuracy				 0
# away_player_5_short_passing				 0
# away_player_5_volleys				 0
# away_player_5_dribbling				 0
# away_player_5_curve				 0
# away_player_5_free_kick_accuracy				 0
# away_player_5_long_passing				 0
# away_player_5_ball_control				 0
# away_player_5_acceleration				 0
# away_player_5_sprint_speed				 0
# away_player_5_agility				 0
# away_player_5_reactions				 0
# away_player_5_balance				 0
# away_player_5_shot_power				 0
# away_player_5_jumping				 0
# away_player_5_stamina				 0
# away_player_5_strength				 0
# away_player_5_long_shots				 0
# away_player_5_aggression				 0
# away_player_5_interceptions				 0
# away_player_5_positioning				 0
# away_player_5_vision				 0
# away_player_5_penalties				 0
# away_player_5_marking				 0
# away_player_5_standing_tackle				 0
# away_player_5_sliding_tackle				 0
# away_player_5_gk_diving				 0
# away_player_5_gk_handling				 0
# away_player_5_gk_kicking				 0
# away_player_5_gk_positioning				 0
# away_player_5_gk_reflexes				 0
# away_player_6_id				 0
# away_player_6_player_fifa_api_id				 0
# away_player_6_player_api_id				 0
# away_player_6_date				 0
# away_player_6_overall_rating				 0
# away_player_6_potential				 0
# away_player_6_preferred_foot				 0
# away_player_6_attacking_work_rate				 0
# away_player_6_defensive_work_rate				 0
# away_player_6_crossing				 0
# away_player_6_finishing				 0
# away_player_6_heading_accuracy				 0
# away_player_6_short_passing				 0
# away_player_6_volleys				 0
# away_player_6_dribbling				 0
# away_player_6_curve				 0
# away_player_6_free_kick_accuracy				 0
# away_player_6_long_passing				 0
# away_player_6_ball_control				 0
# away_player_6_acceleration				 0
# away_player_6_sprint_speed				 0
# away_player_6_agility				 0
# away_player_6_reactions				 0
# away_player_6_balance				 0
# away_player_6_shot_power				 0
# away_player_6_jumping				 0
# away_player_6_stamina				 0
# away_player_6_strength				 0
# away_player_6_long_shots				 0
# away_player_6_aggression				 0
# away_player_6_interceptions				 0
# away_player_6_positioning				 0
# away_player_6_vision				 0
# away_player_6_penalties				 0
# away_player_6_marking				 0
# away_player_6_standing_tackle				 0
# away_player_6_sliding_tackle				 0
# away_player_6_gk_diving				 0
# away_player_6_gk_handling				 0
# away_player_6_gk_kicking				 0
# away_player_6_gk_positioning				 0
# away_player_6_gk_reflexes				 0
# away_player_7_id				 0
# away_player_7_player_fifa_api_id				 0
# away_player_7_player_api_id				 0
# away_player_7_date				 0
# away_player_7_overall_rating				 0
# away_player_7_potential				 0
# away_player_7_preferred_foot				 0
# away_player_7_attacking_work_rate				 0
# away_player_7_defensive_work_rate				 0
# away_player_7_crossing				 0
# away_player_7_finishing				 0
# away_player_7_heading_accuracy				 0
# away_player_7_short_passing				 0
# away_player_7_volleys				 0
# away_player_7_dribbling				 0
# away_player_7_curve				 0
# away_player_7_free_kick_accuracy				 0
# away_player_7_long_passing				 0
# away_player_7_ball_control				 0
# away_player_7_acceleration				 0
# away_player_7_sprint_speed				 0
# away_player_7_agility				 0
# away_player_7_reactions				 0
# away_player_7_balance				 0
# away_player_7_shot_power				 0
# away_player_7_jumping				 0
# away_player_7_stamina				 0
# away_player_7_strength				 0
# away_player_7_long_shots				 0
# away_player_7_aggression				 0
# away_player_7_interceptions				 0
# away_player_7_positioning				 0
# away_player_7_vision				 0
# away_player_7_penalties				 0
# away_player_7_marking				 0
# away_player_7_standing_tackle				 0
# away_player_7_sliding_tackle				 0
# away_player_7_gk_diving				 0
# away_player_7_gk_handling				 0
# away_player_7_gk_kicking				 0
# away_player_7_gk_positioning				 0
# away_player_7_gk_reflexes				 0
# away_player_8_id				 0
# away_player_8_player_fifa_api_id				 0
# away_player_8_player_api_id				 0
# away_player_8_date				 0
# away_player_8_overall_rating				 0
# away_player_8_potential				 0
# away_player_8_preferred_foot				 0
# away_player_8_attacking_work_rate				 0
# away_player_8_defensive_work_rate				 0
# away_player_8_crossing				 0
# away_player_8_finishing				 0
# away_player_8_heading_accuracy				 0
# away_player_8_short_passing				 0
# away_player_8_volleys				 0
# away_player_8_dribbling				 0
# away_player_8_curve				 0
# away_player_8_free_kick_accuracy				 0
# away_player_8_long_passing				 0
# away_player_8_ball_control				 0
# away_player_8_acceleration				 0
# away_player_8_sprint_speed				 0
# away_player_8_agility				 0
# away_player_8_reactions				 0
# away_player_8_balance				 0
# away_player_8_shot_power				 0
# away_player_8_jumping				 0
# away_player_8_stamina				 0
# away_player_8_strength				 0
# away_player_8_long_shots				 0
# away_player_8_aggression				 0
# away_player_8_interceptions				 0
# away_player_8_positioning				 0
# away_player_8_vision				 0
# away_player_8_penalties				 0
# away_player_8_marking				 0
# away_player_8_standing_tackle				 0
# away_player_8_sliding_tackle				 0
# away_player_8_gk_diving				 0
# away_player_8_gk_handling				 0
# away_player_8_gk_kicking				 0
# away_player_8_gk_positioning				 0
# away_player_8_gk_reflexes				 0
# away_player_10_id				 0
# away_player_10_player_fifa_api_id				 0
# away_player_10_player_api_id				 0
# away_player_10_date				 0
# away_player_10_overall_rating				 0
# away_player_10_potential				 0
# away_player_10_preferred_foot				 0
# away_player_10_attacking_work_rate				 0
# away_player_10_defensive_work_rate				 0
# away_player_10_crossing				 0
# away_player_10_finishing				 0
# away_player_10_heading_accuracy				 0
# away_player_10_short_passing				 0
# away_player_10_volleys				 0
# away_player_10_dribbling				 0
# away_player_10_curve				 0
# away_player_10_free_kick_accuracy				 0
# away_player_10_long_passing				 0
# away_player_10_ball_control				 0
# away_player_10_acceleration				 0
# away_player_10_sprint_speed				 0
# away_player_10_agility				 0
# away_player_10_reactions				 0
# away_player_10_balance				 0
# away_player_10_shot_power				 0
# away_player_10_jumping				 0
# away_player_10_stamina				 0
# away_player_10_strength				 0
# away_player_10_long_shots				 0
# away_player_10_aggression				 0
# away_player_10_interceptions				 0
# away_player_10_positioning				 0
# away_player_10_vision				 0
# away_player_10_penalties				 0
# away_player_10_marking				 0
# away_player_10_standing_tackle				 0
# away_player_10_sliding_tackle				 0
# away_player_10_gk_diving				 0
# away_player_10_gk_handling				 0
# away_player_10_gk_kicking				 0
# away_player_10_gk_positioning				 0
# away_player_10_gk_reflexes				 0
# away_player_11_id				 0
# away_player_11_player_fifa_api_id				 0
# away_player_11_player_api_id				 0
# away_player_11_date				 0
# away_player_11_overall_rating				 0
# away_player_11_potential				 0
# away_player_11_preferred_foot				 0
# away_player_11_attacking_work_rate				 0
# away_player_11_defensive_work_rate				 0
# away_player_11_crossing				 0
# away_player_11_finishing				 0
# away_player_11_heading_accuracy				 0
# away_player_11_short_passing				 0
# away_player_11_volleys				 0
# away_player_11_dribbling				 0
# away_player_11_curve				 0
# away_player_11_free_kick_accuracy				 0
# away_player_11_long_passing				 0
# away_player_11_ball_control				 0
# away_player_11_acceleration				 0
# away_player_11_sprint_speed				 0
# away_player_11_agility				 0
# away_player_11_reactions				 0
# away_player_11_balance				 0
# away_player_11_shot_power				 0
# away_player_11_jumping				 0
# away_player_11_stamina				 0
# away_player_11_strength				 0
# away_player_11_long_shots				 0
# away_player_11_aggression				 0
# away_player_11_interceptions				 0
# away_player_11_positioning				 0
# away_player_11_vision				 0
# away_player_11_penalties				 0
# away_player_11_marking				 0
# away_player_11_standing_tackle				 0
# away_player_11_sliding_tackle				 0
# away_player_11_gk_diving				 0
# away_player_11_gk_handling				 0
# away_player_11_gk_kicking				 0
# away_player_11_gk_positioning				 0
# away_player_11_gk_reflexes				 0
# away_player_2_acceleration				 0
# away_player_2_aggression				 0
# away_player_2_agility				 0
# away_player_2_attacking_work_rate				 0
# away_player_2_balance				 0
# away_player_2_ball_control				 0
# away_player_2_crossing				 0
# away_player_2_curve				 0
# away_player_2_date				 0
# away_player_2_defensive_work_rate				 0
# away_player_2_dribbling				 0
# away_player_2_finishing				 0
# away_player_2_free_kick_accuracy				 0
# away_player_2_gk_diving				 0
# away_player_2_gk_handling				 0
# away_player_2_gk_kicking				 0
# away_player_2_gk_positioning				 0
# away_player_2_gk_reflexes				 0
# away_player_2_heading_accuracy				 0
# away_player_2_id				 0
# away_player_2_interceptions				 0
# away_player_2_jumping				 0
# away_player_2_long_passing				 0
# away_player_2_long_shots				 0
# away_player_2_marking				 0
# away_player_2_overall_rating				 0
# away_player_2_penalties				 0
# away_player_2_player_api_id				 0
# away_player_2_player_fifa_api_id				 0
# away_player_2_positioning				 0
# away_player_2_potential				 0
# away_player_2_preferred_foot				 0
# away_player_2_reactions				 0
# away_player_2_short_passing				 0
# away_player_2_shot_power				 0
# away_player_2_sliding_tackle				 0
# away_player_2_sprint_speed				 0
# away_player_2_stamina				 0
# away_player_2_standing_tackle				 0
# away_player_2_strength				 0
# away_player_2_vision				 0
# away_player_2_volleys				 0
# away_player_9_acceleration				 0
# away_player_9_aggression				 0
# away_player_9_agility				 0
# away_player_9_attacking_work_rate				 0
# away_player_9_balance				 0
# away_player_9_ball_control				 0
# away_player_9_crossing				 0
# away_player_9_curve				 0
# away_player_9_date				 0
# away_player_9_defensive_work_rate				 0
# away_player_9_dribbling				 0
# away_player_9_finishing				 0
# away_player_9_free_kick_accuracy				 0
# away_player_9_gk_diving				 0
# away_player_9_gk_handling				 0
# away_player_9_gk_kicking				 0
# away_player_9_gk_positioning				 0
# away_player_9_gk_reflexes				 0
# away_player_9_heading_accuracy				 0
# away_player_9_id				 0
# away_player_9_interceptions				 0
# away_player_9_jumping				 0
# away_player_9_long_passing				 0
# away_player_9_long_shots				 0
# away_player_9_marking				 0
# away_player_9_overall_rating				 0
# away_player_9_penalties				 0
# away_player_9_player_api_id				 0
# away_player_9_player_fifa_api_id				 0
# away_player_9_positioning				 0
# away_player_9_potential				 0
# away_player_9_preferred_foot				 0
# away_player_9_reactions				 0
# away_player_9_short_passing				 0
# away_player_9_shot_power				 0
# away_player_9_sliding_tackle				 0
# away_player_9_sprint_speed				 0
# away_player_9_stamina				 0
# away_player_9_standing_tackle				 0
# away_player_9_strength				 0
# away_player_9_vision				 0
# away_player_9_volleys				 0
# home_player_2_acceleration				 0
# home_player_2_aggression				 0
# home_player_2_agility				 0
# home_player_2_attacking_work_rate				 0
# home_player_2_balance				 0
# home_player_2_ball_control				 0
# home_player_2_crossing				 0
# home_player_2_curve				 0
# home_player_2_date				 0
# home_player_2_defensive_work_rate				 0
# home_player_2_dribbling				 0
# home_player_2_finishing				 0
# home_player_2_free_kick_accuracy				 0
# home_player_2_gk_diving				 0
# home_player_2_gk_handling				 0
# home_player_2_gk_kicking				 0
# home_player_2_gk_positioning				 0
# home_player_2_gk_reflexes				 0
# home_player_2_heading_accuracy				 0
# home_player_2_id				 0
# home_player_2_interceptions				 0
# home_player_2_jumping				 0
# home_player_2_long_passing				 0
# home_player_2_long_shots				 0
# home_player_2_marking				 0
# home_player_2_overall_rating				 0
# home_player_2_penalties				 0
# home_player_2_player_api_id				 0
# home_player_2_player_fifa_api_id				 0
# home_player_2_positioning				 0
# home_player_2_potential				 0
# home_player_2_preferred_foot				 0
# home_player_2_reactions				 0
# home_player_2_short_passing				 0
# home_player_2_shot_power				 0
# home_player_2_sliding_tackle				 0
# home_player_2_sprint_speed				 0
# home_player_2_stamina				 0
# home_player_2_standing_tackle				 0
# home_player_2_strength				 0
# home_player_2_vision				 0
# home_player_2_volleys				 0
# home_player_3_acceleration				 0
# home_player_3_aggression				 0
# home_player_3_agility				 0
# home_player_3_attacking_work_rate				 0
# home_player_3_balance				 0
# home_player_3_ball_control				 0
# home_player_3_crossing				 0
# home_player_3_curve				 0
# home_player_3_date				 0
# home_player_3_defensive_work_rate				 0
# home_player_3_dribbling				 0
# home_player_3_finishing				 0
# home_player_3_free_kick_accuracy				 0
# home_player_3_gk_diving				 0
# home_player_3_gk_handling				 0
# home_player_3_gk_kicking				 0
# home_player_3_gk_positioning				 0
# home_player_3_gk_reflexes				 0
# home_player_3_heading_accuracy				 0
# home_player_3_id				 0
# home_player_3_interceptions				 0
# home_player_3_jumping				 0
# home_player_3_long_passing				 0
# home_player_3_long_shots				 0
# home_player_3_marking				 0
# home_player_3_overall_rating				 0
# home_player_3_penalties				 0
# home_player_3_player_api_id				 0
# home_player_3_player_fifa_api_id				 0
# home_player_3_positioning				 0
# home_player_3_potential				 0
# home_player_3_preferred_foot				 0
# home_player_3_reactions				 0
# home_player_3_short_passing				 0
# home_player_3_shot_power				 0
# home_player_3_sliding_tackle				 0
# home_player_3_sprint_speed				 0
# home_player_3_stamina				 0
# home_player_3_standing_tackle				 0
# home_player_3_strength				 0
# home_player_3_vision				 0
# home_player_3_volleys				 0
# home_player_7_acceleration				 0
# home_player_7_aggression				 0
# home_player_7_agility				 0
# home_player_7_attacking_work_rate				 0
# home_player_7_balance				 0
# home_player_7_ball_control				 0
# home_player_7_crossing				 0
# home_player_7_curve				 0
# home_player_7_date				 0
# home_player_7_defensive_work_rate				 0
# home_player_7_dribbling				 0
# home_player_7_finishing				 0
# home_player_7_free_kick_accuracy				 0
# home_player_7_gk_diving				 0
# home_player_7_gk_handling				 0
# home_player_7_gk_kicking				 0
# home_player_7_gk_positioning				 0
# home_player_7_gk_reflexes				 0
# home_player_7_heading_accuracy				 0
# home_player_7_id				 0
# home_player_7_interceptions				 0
# home_player_7_jumping				 0
# home_player_7_long_passing				 0
# home_player_7_long_shots				 0
# home_player_7_marking				 0
# home_player_7_overall_rating				 0
# home_player_7_penalties				 0
# home_player_7_player_api_id				 0
# home_player_7_player_fifa_api_id				 0
# home_player_7_positioning				 0
# home_player_7_potential				 0
# home_player_7_preferred_foot				 0
# home_player_7_reactions				 0
# home_player_7_short_passing				 0
# home_player_7_shot_power				 0
# home_player_7_sliding_tackle				 0
# home_player_7_sprint_speed				 0
# home_player_7_stamina				 0
# home_player_7_standing_tackle				 0
# home_player_7_strength				 0
# home_player_7_vision				 0
# home_player_7_volleys				 0

# %%
#Check dtypes
res.astype({"id":"int32"}).dtypes
# Out:
# id                                int32
# country_id                       object
# league_id                        object
# season                           object
# stage                            object
#                                   ...
# away_player_11_gk_diving         object
# away_player_11_gk_handling       object
# away_player_11_gk_kicking        object
# away_player_11_gk_positioning    object
# away_player_11_gk_reflexes       object
# Length: 846, dtype: object

# %%
#Print cols

colList=list(res.columns)
for i,t in enumerate(res.dtypes):
    print(colList[i],t)
# Out:
# id object
# country_id object
# league_id object
# season object
# stage object
# date object
# match_api_id object
# home_team_api_id object
# away_team_api_id object
# result object
# home_player_1_overall_rating float64
# home_player_1_potential float64
# home_player_1_preferred_foot object
# home_player_1_attacking_work_rate object
# home_player_1_defensive_work_rate object
# home_player_1_crossing float64
# home_player_1_finishing float64
# home_player_1_heading_accuracy float64
# home_player_1_short_passing float64
# home_player_1_volleys float64
# home_player_1_dribbling float64
# home_player_1_curve float64
# home_player_1_free_kick_accuracy float64
# home_player_1_long_passing float64
# home_player_1_ball_control float64
# home_player_1_acceleration float64
# home_player_1_sprint_speed float64
# home_player_1_agility float64
# home_player_1_reactions float64
# home_player_1_balance float64
# home_player_1_shot_power float64
# home_player_1_jumping float64
# home_player_1_stamina float64
# home_player_1_strength float64
# home_player_1_long_shots float64
# home_player_1_aggression float64
# home_player_1_interceptions float64
# home_player_1_positioning float64
# home_player_1_vision float64
# home_player_1_penalties float64
# home_player_1_marking float64
# home_player_1_standing_tackle float64
# home_player_1_sliding_tackle float64
# home_player_1_gk_diving float64
# home_player_1_gk_handling float64
# home_player_1_gk_kicking float64
# home_player_1_gk_positioning float64
# home_player_1_gk_reflexes float64
# home_player_2_overall_rating object
# home_player_2_potential object
# home_player_2_preferred_foot object
# home_player_2_attacking_work_rate object
# home_player_2_defensive_work_rate object
# home_player_2_crossing object
# home_player_2_finishing object
# home_player_2_heading_accuracy object
# home_player_2_short_passing object
# home_player_2_volleys object
# home_player_2_dribbling object
# home_player_2_curve object
# home_player_2_free_kick_accuracy object
# home_player_2_long_passing object
# home_player_2_ball_control object
# home_player_2_acceleration object
# home_player_2_sprint_speed object
# home_player_2_agility object
# home_player_2_reactions object
# home_player_2_balance object
# home_player_2_shot_power object
# home_player_2_jumping object
# home_player_2_stamina object
# home_player_2_strength object
# home_player_2_long_shots object
# home_player_2_aggression object
# home_player_2_interceptions object
# home_player_2_positioning object
# home_player_2_vision object
# home_player_2_penalties object
# home_player_2_marking object
# home_player_2_standing_tackle object
# home_player_2_sliding_tackle object
# home_player_2_gk_diving object
# home_player_2_gk_handling object
# home_player_2_gk_kicking object
# home_player_2_gk_positioning object
# home_player_2_gk_reflexes object
# home_player_3_overall_rating object
# home_player_3_potential object
# home_player_3_preferred_foot object
# home_player_3_attacking_work_rate object
# home_player_3_defensive_work_rate object
# home_player_3_crossing object
# home_player_3_finishing object
# home_player_3_heading_accuracy object
# home_player_3_short_passing object
# home_player_3_volleys object
# home_player_3_dribbling object
# home_player_3_curve object
# home_player_3_free_kick_accuracy object
# home_player_3_long_passing object
# home_player_3_ball_control object
# home_player_3_acceleration object
# home_player_3_sprint_speed object
# home_player_3_agility object
# home_player_3_reactions object
# home_player_3_balance object
# home_player_3_shot_power object
# home_player_3_jumping object
# home_player_3_stamina object
# home_player_3_strength object
# home_player_3_long_shots object
# home_player_3_aggression object
# home_player_3_interceptions object
# home_player_3_positioning object
# home_player_3_vision object
# home_player_3_penalties object
# home_player_3_marking object
# home_player_3_standing_tackle object
# home_player_3_sliding_tackle object
# home_player_3_gk_diving object
# home_player_3_gk_handling object
# home_player_3_gk_kicking object
# home_player_3_gk_positioning object
# home_player_3_gk_reflexes object
# home_player_4_overall_rating float64
# home_player_4_potential float64
# home_player_4_preferred_foot object
# home_player_4_attacking_work_rate object
# home_player_4_defensive_work_rate object
# home_player_4_crossing float64
# home_player_4_finishing float64
# home_player_4_heading_accuracy float64
# home_player_4_short_passing float64
# home_player_4_volleys float64
# home_player_4_dribbling float64
# home_player_4_curve float64
# home_player_4_free_kick_accuracy float64
# home_player_4_long_passing float64
# home_player_4_ball_control float64
# home_player_4_acceleration float64
# home_player_4_sprint_speed float64
# home_player_4_agility float64
# home_player_4_reactions float64
# home_player_4_balance float64
# home_player_4_shot_power float64
# home_player_4_jumping float64
# home_player_4_stamina float64
# home_player_4_strength float64
# home_player_4_long_shots float64
# home_player_4_aggression float64
# home_player_4_interceptions float64
# home_player_4_positioning float64
# home_player_4_vision float64
# home_player_4_penalties float64
# home_player_4_marking float64
# home_player_4_standing_tackle float64
# home_player_4_sliding_tackle float64
# home_player_4_gk_diving float64
# home_player_4_gk_handling float64
# home_player_4_gk_kicking float64
# home_player_4_gk_positioning float64
# home_player_4_gk_reflexes float64
# home_player_5_overall_rating float64
# home_player_5_potential float64
# home_player_5_preferred_foot object
# home_player_5_attacking_work_rate object
# home_player_5_defensive_work_rate object
# home_player_5_crossing float64
# home_player_5_finishing float64
# home_player_5_heading_accuracy float64
# home_player_5_short_passing float64
# home_player_5_volleys float64
# home_player_5_dribbling float64
# home_player_5_curve float64
# home_player_5_free_kick_accuracy float64
# home_player_5_long_passing float64
# home_player_5_ball_control float64
# home_player_5_acceleration float64
# home_player_5_sprint_speed float64
# home_player_5_agility float64
# home_player_5_reactions float64
# home_player_5_balance float64
# home_player_5_shot_power float64
# home_player_5_jumping float64
# home_player_5_stamina float64
# home_player_5_strength float64
# home_player_5_long_shots float64
# home_player_5_aggression float64
# home_player_5_interceptions float64
# home_player_5_positioning float64
# home_player_5_vision float64
# home_player_5_penalties float64
# home_player_5_marking float64
# home_player_5_standing_tackle float64
# home_player_5_sliding_tackle float64
# home_player_5_gk_diving float64
# home_player_5_gk_handling float64
# home_player_5_gk_kicking float64
# home_player_5_gk_positioning float64
# home_player_5_gk_reflexes float64
# home_player_6_overall_rating float64
# home_player_6_potential float64
# home_player_6_preferred_foot object
# home_player_6_attacking_work_rate object
# home_player_6_defensive_work_rate object
# home_player_6_crossing float64
# home_player_6_finishing float64
# home_player_6_heading_accuracy float64
# home_player_6_short_passing float64
# home_player_6_volleys float64
# home_player_6_dribbling float64
# home_player_6_curve float64
# home_player_6_free_kick_accuracy float64
# home_player_6_long_passing float64
# home_player_6_ball_control float64
# home_player_6_acceleration float64
# home_player_6_sprint_speed float64
# home_player_6_agility float64
# home_player_6_reactions float64
# home_player_6_balance float64
# home_player_6_shot_power float64
# home_player_6_jumping float64
# home_player_6_stamina float64
# home_player_6_strength float64
# home_player_6_long_shots float64
# home_player_6_aggression float64
# home_player_6_interceptions float64
# home_player_6_positioning float64
# home_player_6_vision float64
# home_player_6_penalties float64
# home_player_6_marking float64
# home_player_6_standing_tackle float64
# home_player_6_sliding_tackle float64
# home_player_6_gk_diving float64
# home_player_6_gk_handling float64
# home_player_6_gk_kicking float64
# home_player_6_gk_positioning float64
# home_player_6_gk_reflexes float64
# home_player_7_overall_rating object
# home_player_7_potential object
# home_player_7_preferred_foot object
# home_player_7_attacking_work_rate object
# home_player_7_defensive_work_rate object
# home_player_7_crossing object
# home_player_7_finishing object
# home_player_7_heading_accuracy object
# home_player_7_short_passing object
# home_player_7_volleys object
# home_player_7_dribbling object
# home_player_7_curve object
# home_player_7_free_kick_accuracy object
# home_player_7_long_passing object
# home_player_7_ball_control object
# home_player_7_acceleration object
# home_player_7_sprint_speed object
# home_player_7_agility object
# home_player_7_reactions object
# home_player_7_balance object
# home_player_7_shot_power object
# home_player_7_jumping object
# home_player_7_stamina object
# home_player_7_strength object
# home_player_7_long_shots object
# home_player_7_aggression object
# home_player_7_interceptions object
# home_player_7_positioning object
# home_player_7_vision object
# home_player_7_penalties object
# home_player_7_marking object
# home_player_7_standing_tackle object
# home_player_7_sliding_tackle object
# home_player_7_gk_diving object
# home_player_7_gk_handling object
# home_player_7_gk_kicking object
# home_player_7_gk_positioning object
# home_player_7_gk_reflexes object
# home_player_8_overall_rating float64
# home_player_8_potential float64
# home_player_8_preferred_foot object
# home_player_8_attacking_work_rate object
# home_player_8_defensive_work_rate object
# home_player_8_crossing float64
# home_player_8_finishing float64
# home_player_8_heading_accuracy float64
# home_player_8_short_passing float64
# home_player_8_volleys float64
# home_player_8_dribbling float64
# home_player_8_curve float64
# home_player_8_free_kick_accuracy float64
# home_player_8_long_passing float64
# home_player_8_ball_control float64
# home_player_8_acceleration float64
# home_player_8_sprint_speed float64
# home_player_8_agility float64
# home_player_8_reactions float64
# home_player_8_balance float64
# home_player_8_shot_power float64
# home_player_8_jumping float64
# home_player_8_stamina float64
# home_player_8_strength float64
# home_player_8_long_shots float64
# home_player_8_aggression float64
# home_player_8_interceptions float64
# home_player_8_positioning float64
# home_player_8_vision float64
# home_player_8_penalties float64
# home_player_8_marking float64
# home_player_8_standing_tackle float64
# home_player_8_sliding_tackle float64
# home_player_8_gk_diving float64
# home_player_8_gk_handling float64
# home_player_8_gk_kicking float64
# home_player_8_gk_positioning float64
# home_player_8_gk_reflexes float64
# home_player_9_overall_rating object
# home_player_9_potential object
# home_player_9_preferred_foot object
# home_player_9_attacking_work_rate object
# home_player_9_defensive_work_rate object
# home_player_9_crossing object
# home_player_9_finishing object
# home_player_9_heading_accuracy object
# home_player_9_short_passing object
# home_player_9_volleys object
# home_player_9_dribbling object
# home_player_9_curve object
# home_player_9_free_kick_accuracy object
# home_player_9_long_passing object
# home_player_9_ball_control object
# home_player_9_acceleration object
# home_player_9_sprint_speed object
# home_player_9_agility object
# home_player_9_reactions object
# home_player_9_balance object
# home_player_9_shot_power object
# home_player_9_jumping object
# home_player_9_stamina object
# home_player_9_strength object
# home_player_9_long_shots object
# home_player_9_aggression object
# home_player_9_interceptions object
# home_player_9_positioning object
# home_player_9_vision object
# home_player_9_penalties object
# home_player_9_marking object
# home_player_9_standing_tackle object
# home_player_9_sliding_tackle object
# home_player_9_gk_diving object
# home_player_9_gk_handling object
# home_player_9_gk_kicking object
# home_player_9_gk_positioning object
# home_player_9_gk_reflexes object
# home_player_10_overall_rating float64
# home_player_10_potential float64
# home_player_10_preferred_foot object
# home_player_10_attacking_work_rate object
# home_player_10_defensive_work_rate object
# home_player_10_crossing float64
# home_player_10_finishing float64
# home_player_10_heading_accuracy float64
# home_player_10_short_passing float64
# home_player_10_volleys float64
# home_player_10_dribbling float64
# home_player_10_curve float64
# home_player_10_free_kick_accuracy float64
# home_player_10_long_passing float64
# home_player_10_ball_control float64
# home_player_10_acceleration float64
# home_player_10_sprint_speed float64
# home_player_10_agility float64
# home_player_10_reactions float64
# home_player_10_balance float64
# home_player_10_shot_power float64
# home_player_10_jumping float64
# home_player_10_stamina float64
# home_player_10_strength float64
# home_player_10_long_shots float64
# home_player_10_aggression float64
# home_player_10_interceptions float64
# home_player_10_positioning float64
# home_player_10_vision float64
# home_player_10_penalties float64
# home_player_10_marking float64
# home_player_10_standing_tackle float64
# home_player_10_sliding_tackle float64
# home_player_10_gk_diving float64
# home_player_10_gk_handling float64
# home_player_10_gk_kicking float64
# home_player_10_gk_positioning float64
# home_player_10_gk_reflexes float64
# home_player_11_overall_rating float64
# home_player_11_potential float64
# home_player_11_preferred_foot object
# home_player_11_attacking_work_rate object
# home_player_11_defensive_work_rate object
# home_player_11_crossing float64
# home_player_11_finishing float64
# home_player_11_heading_accuracy float64
# home_player_11_short_passing float64
# home_player_11_volleys float64
# home_player_11_dribbling float64
# home_player_11_curve float64
# home_player_11_free_kick_accuracy float64
# home_player_11_long_passing float64
# home_player_11_ball_control float64
# home_player_11_acceleration float64
# home_player_11_sprint_speed float64
# home_player_11_agility float64
# home_player_11_reactions float64
# home_player_11_balance float64
# home_player_11_shot_power float64
# home_player_11_jumping float64
# home_player_11_stamina float64
# home_player_11_strength float64
# home_player_11_long_shots float64
# home_player_11_aggression float64
# home_player_11_interceptions float64
# home_player_11_positioning float64
# home_player_11_vision float64
# home_player_11_penalties float64
# home_player_11_marking float64
# home_player_11_standing_tackle float64
# home_player_11_sliding_tackle float64
# home_player_11_gk_diving float64
# home_player_11_gk_handling float64
# home_player_11_gk_kicking float64
# home_player_11_gk_positioning float64
# home_player_11_gk_reflexes float64
# away_player_1_overall_rating float64
# away_player_1_potential float64
# away_player_1_preferred_foot object
# away_player_1_attacking_work_rate object
# away_player_1_defensive_work_rate object
# away_player_1_crossing float64
# away_player_1_finishing float64
# away_player_1_heading_accuracy float64
# away_player_1_short_passing float64
# away_player_1_volleys float64
# away_player_1_dribbling float64
# away_player_1_curve float64
# away_player_1_free_kick_accuracy float64
# away_player_1_long_passing float64
# away_player_1_ball_control float64
# away_player_1_acceleration float64
# away_player_1_sprint_speed float64
# away_player_1_agility float64
# away_player_1_reactions float64
# away_player_1_balance float64
# away_player_1_shot_power float64
# away_player_1_jumping float64
# away_player_1_stamina float64
# away_player_1_strength float64
# away_player_1_long_shots float64
# away_player_1_aggression float64
# away_player_1_interceptions float64
# away_player_1_positioning float64
# away_player_1_vision float64
# away_player_1_penalties float64
# away_player_1_marking float64
# away_player_1_standing_tackle float64
# away_player_1_sliding_tackle float64
# away_player_1_gk_diving float64
# away_player_1_gk_handling float64
# away_player_1_gk_kicking float64
# away_player_1_gk_positioning float64
# away_player_1_gk_reflexes float64
# away_player_2_overall_rating object
# away_player_2_potential object
# away_player_2_preferred_foot object
# away_player_2_attacking_work_rate object
# away_player_2_defensive_work_rate object
# away_player_2_crossing object
# away_player_2_finishing object
# away_player_2_heading_accuracy object
# away_player_2_short_passing object
# away_player_2_volleys object
# away_player_2_dribbling object
# away_player_2_curve object
# away_player_2_free_kick_accuracy object
# away_player_2_long_passing object
# away_player_2_ball_control object
# away_player_2_acceleration object
# away_player_2_sprint_speed object
# away_player_2_agility object
# away_player_2_reactions object
# away_player_2_balance object
# away_player_2_shot_power object
# away_player_2_jumping object
# away_player_2_stamina object
# away_player_2_strength object
# away_player_2_long_shots object
# away_player_2_aggression object
# away_player_2_interceptions object
# away_player_2_positioning object
# away_player_2_vision object
# away_player_2_penalties object
# away_player_2_marking object
# away_player_2_standing_tackle object
# away_player_2_sliding_tackle object
# away_player_2_gk_diving object
# away_player_2_gk_handling object
# away_player_2_gk_kicking object
# away_player_2_gk_positioning object
# away_player_2_gk_reflexes object
# away_player_3_overall_rating float64
# away_player_3_potential float64
# away_player_3_preferred_foot object
# away_player_3_attacking_work_rate object
# away_player_3_defensive_work_rate object
# away_player_3_crossing float64
# away_player_3_finishing float64
# away_player_3_heading_accuracy float64
# away_player_3_short_passing float64
# away_player_3_volleys float64
# away_player_3_dribbling float64
# away_player_3_curve float64
# away_player_3_free_kick_accuracy float64
# away_player_3_long_passing float64
# away_player_3_ball_control float64
# away_player_3_acceleration float64
# away_player_3_sprint_speed float64
# away_player_3_agility float64
# away_player_3_reactions float64
# away_player_3_balance float64
# away_player_3_shot_power float64
# away_player_3_jumping float64
# away_player_3_stamina float64
# away_player_3_strength float64
# away_player_3_long_shots float64
# away_player_3_aggression float64
# away_player_3_interceptions float64
# away_player_3_positioning float64
# away_player_3_vision float64
# away_player_3_penalties float64
# away_player_3_marking float64
# away_player_3_standing_tackle float64
# away_player_3_sliding_tackle float64
# away_player_3_gk_diving float64
# away_player_3_gk_handling float64
# away_player_3_gk_kicking float64
# away_player_3_gk_positioning float64
# away_player_3_gk_reflexes float64
# away_player_4_overall_rating float64
# away_player_4_potential float64
# away_player_4_preferred_foot object
# away_player_4_attacking_work_rate object
# away_player_4_defensive_work_rate object
# away_player_4_crossing float64
# away_player_4_finishing float64
# away_player_4_heading_accuracy float64
# away_player_4_short_passing float64
# away_player_4_volleys float64
# away_player_4_dribbling float64
# away_player_4_curve float64
# away_player_4_free_kick_accuracy float64
# away_player_4_long_passing float64
# away_player_4_ball_control float64
# away_player_4_acceleration float64
# away_player_4_sprint_speed float64
# away_player_4_agility float64
# away_player_4_reactions float64
# away_player_4_balance float64
# away_player_4_shot_power float64
# away_player_4_jumping float64
# away_player_4_stamina float64
# away_player_4_strength float64
# away_player_4_long_shots float64
# away_player_4_aggression float64
# away_player_4_interceptions float64
# away_player_4_positioning float64
# away_player_4_vision float64
# away_player_4_penalties float64
# away_player_4_marking float64
# away_player_4_standing_tackle float64
# away_player_4_sliding_tackle float64
# away_player_4_gk_diving float64
# away_player_4_gk_handling float64
# away_player_4_gk_kicking float64
# away_player_4_gk_positioning float64
# away_player_4_gk_reflexes float64
# away_player_5_overall_rating float64
# away_player_5_potential float64
# away_player_5_preferred_foot object
# away_player_5_attacking_work_rate object
# away_player_5_defensive_work_rate object
# away_player_5_crossing float64
# away_player_5_finishing float64
# away_player_5_heading_accuracy float64
# away_player_5_short_passing float64
# away_player_5_volleys float64
# away_player_5_dribbling float64
# away_player_5_curve float64
# away_player_5_free_kick_accuracy float64
# away_player_5_long_passing float64
# away_player_5_ball_control float64
# away_player_5_acceleration float64
# away_player_5_sprint_speed float64
# away_player_5_agility float64
# away_player_5_reactions float64
# away_player_5_balance float64
# away_player_5_shot_power float64
# away_player_5_jumping float64
# away_player_5_stamina float64
# away_player_5_strength float64
# away_player_5_long_shots float64
# away_player_5_aggression float64
# away_player_5_interceptions float64
# away_player_5_positioning float64
# away_player_5_vision float64
# away_player_5_penalties float64
# away_player_5_marking float64
# away_player_5_standing_tackle float64
# away_player_5_sliding_tackle float64
# away_player_5_gk_diving float64
# away_player_5_gk_handling float64
# away_player_5_gk_kicking float64
# away_player_5_gk_positioning float64
# away_player_5_gk_reflexes float64
# away_player_6_overall_rating object
# away_player_6_potential object
# away_player_6_preferred_foot object
# away_player_6_attacking_work_rate object
# away_player_6_defensive_work_rate object
# away_player_6_crossing object
# away_player_6_finishing object
# away_player_6_heading_accuracy object
# away_player_6_short_passing object
# away_player_6_volleys object
# away_player_6_dribbling object
# away_player_6_curve object
# away_player_6_free_kick_accuracy object
# away_player_6_long_passing object
# away_player_6_ball_control object
# away_player_6_acceleration object
# away_player_6_sprint_speed object
# away_player_6_agility object
# away_player_6_reactions object
# away_player_6_balance object
# away_player_6_shot_power object
# away_player_6_jumping object
# away_player_6_stamina object
# away_player_6_strength object
# away_player_6_long_shots object
# away_player_6_aggression object
# away_player_6_interceptions object
# away_player_6_positioning object
# away_player_6_vision object
# away_player_6_penalties object
# away_player_6_marking object
# away_player_6_standing_tackle object
# away_player_6_sliding_tackle object
# away_player_6_gk_diving object
# away_player_6_gk_handling object
# away_player_6_gk_kicking object
# away_player_6_gk_positioning object
# away_player_6_gk_reflexes object
# away_player_7_overall_rating float64
# away_player_7_potential float64
# away_player_7_preferred_foot object
# away_player_7_attacking_work_rate object
# away_player_7_defensive_work_rate object
# away_player_7_crossing float64
# away_player_7_finishing float64
# away_player_7_heading_accuracy float64
# away_player_7_short_passing float64
# away_player_7_volleys float64
# away_player_7_dribbling float64
# away_player_7_curve float64
# away_player_7_free_kick_accuracy float64
# away_player_7_long_passing float64
# away_player_7_ball_control float64
# away_player_7_acceleration float64
# away_player_7_sprint_speed float64
# away_player_7_agility float64
# away_player_7_reactions float64
# away_player_7_balance float64
# away_player_7_shot_power float64
# away_player_7_jumping float64
# away_player_7_stamina float64
# away_player_7_strength float64
# away_player_7_long_shots float64
# away_player_7_aggression float64
# away_player_7_interceptions float64
# away_player_7_positioning float64
# away_player_7_vision float64
# away_player_7_penalties float64
# away_player_7_marking float64
# away_player_7_standing_tackle float64
# away_player_7_sliding_tackle float64
# away_player_7_gk_diving float64
# away_player_7_gk_handling float64
# away_player_7_gk_kicking float64
# away_player_7_gk_positioning float64
# away_player_7_gk_reflexes float64
# away_player_8_overall_rating float64
# away_player_8_potential float64
# away_player_8_preferred_foot object
# away_player_8_attacking_work_rate object
# away_player_8_defensive_work_rate object
# away_player_8_crossing float64
# away_player_8_finishing float64
# away_player_8_heading_accuracy float64
# away_player_8_short_passing float64
# away_player_8_volleys float64
# away_player_8_dribbling float64
# away_player_8_curve float64
# away_player_8_free_kick_accuracy float64
# away_player_8_long_passing float64
# away_player_8_ball_control float64
# away_player_8_acceleration float64
# away_player_8_sprint_speed float64
# away_player_8_agility float64
# away_player_8_reactions float64
# away_player_8_balance float64
# away_player_8_shot_power float64
# away_player_8_jumping float64
# away_player_8_stamina float64
# away_player_8_strength float64
# away_player_8_long_shots float64
# away_player_8_aggression float64
# away_player_8_interceptions float64
# away_player_8_positioning float64
# away_player_8_vision float64
# away_player_8_penalties float64
# away_player_8_marking float64
# away_player_8_standing_tackle float64
# away_player_8_sliding_tackle float64
# away_player_8_gk_diving float64
# away_player_8_gk_handling float64
# away_player_8_gk_kicking float64
# away_player_8_gk_positioning float64
# away_player_8_gk_reflexes float64
# away_player_9_overall_rating object
# away_player_9_potential object
# away_player_9_preferred_foot object
# away_player_9_attacking_work_rate object
# away_player_9_defensive_work_rate object
# away_player_9_crossing object
# away_player_9_finishing object
# away_player_9_heading_accuracy object
# away_player_9_short_passing object
# away_player_9_volleys object
# away_player_9_dribbling object
# away_player_9_curve object
# away_player_9_free_kick_accuracy object
# away_player_9_long_passing object
# away_player_9_ball_control object
# away_player_9_acceleration object
# away_player_9_sprint_speed object
# away_player_9_agility object
# away_player_9_reactions object
# away_player_9_balance object
# away_player_9_shot_power object
# away_player_9_jumping object
# away_player_9_stamina object
# away_player_9_strength object
# away_player_9_long_shots object
# away_player_9_aggression object
# away_player_9_interceptions object
# away_player_9_positioning object
# away_player_9_vision object
# away_player_9_penalties object
# away_player_9_marking object
# away_player_9_standing_tackle object
# away_player_9_sliding_tackle object
# away_player_9_gk_diving object
# away_player_9_gk_handling object
# away_player_9_gk_kicking object
# away_player_9_gk_positioning object
# away_player_9_gk_reflexes object
# away_player_10_overall_rating float64
# away_player_10_potential float64
# away_player_10_preferred_foot object
# away_player_10_attacking_work_rate object
# away_player_10_defensive_work_rate object
# away_player_10_crossing float64
# away_player_10_finishing float64
# away_player_10_heading_accuracy float64
# away_player_10_short_passing float64
# away_player_10_volleys float64
# away_player_10_dribbling float64
# away_player_10_curve float64
# away_player_10_free_kick_accuracy float64
# away_player_10_long_passing float64
# away_player_10_ball_control float64
# away_player_10_acceleration float64
# away_player_10_sprint_speed float64
# away_player_10_agility float64
# away_player_10_reactions float64
# away_player_10_balance float64
# away_player_10_shot_power float64
# away_player_10_jumping float64
# away_player_10_stamina float64
# away_player_10_strength float64
# away_player_10_long_shots float64
# away_player_10_aggression float64
# away_player_10_interceptions float64
# away_player_10_positioning float64
# away_player_10_vision float64
# away_player_10_penalties float64
# away_player_10_marking float64
# away_player_10_standing_tackle float64
# away_player_10_sliding_tackle float64
# away_player_10_gk_diving float64
# away_player_10_gk_handling float64
# away_player_10_gk_kicking float64
# away_player_10_gk_positioning float64
# away_player_10_gk_reflexes float64
# away_player_11_overall_rating float64
# away_player_11_potential float64
# away_player_11_preferred_foot object
# away_player_11_attacking_work_rate object
# away_player_11_defensive_work_rate object
# away_player_11_crossing float64
# away_player_11_finishing float64
# away_player_11_heading_accuracy float64
# away_player_11_short_passing float64
# away_player_11_volleys float64
# away_player_11_dribbling float64
# away_player_11_curve float64
# away_player_11_free_kick_accuracy float64
# away_player_11_long_passing float64
# away_player_11_ball_control float64
# away_player_11_acceleration float64
# away_player_11_sprint_speed float64
# away_player_11_agility float64
# away_player_11_reactions float64
# away_player_11_balance float64
# away_player_11_shot_power float64
# away_player_11_jumping float64
# away_player_11_stamina float64
# away_player_11_strength float64
# away_player_11_long_shots float64
# away_player_11_aggression float64
# away_player_11_interceptions float64
# away_player_11_positioning float64
# away_player_11_vision float64
# away_player_11_penalties float64
# away_player_11_marking float64
# away_player_11_standing_tackle float64
# away_player_11_sliding_tackle float64
# away_player_11_gk_diving float64
# away_player_11_gk_handling float64
# away_player_11_gk_kicking float64
# away_player_11_gk_positioning float64
# away_player_11_gk_reflexes float64
